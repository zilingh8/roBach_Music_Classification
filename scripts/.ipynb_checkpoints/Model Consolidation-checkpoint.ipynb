# %% [markdown]
# # Model Consolidation

# %% [markdown]
# ### Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt   
# %matplotlib inline
from music21 import *
from IPython.display import Audio
from intervaltree import Interval,IntervalTree
import pandas as pd
import seaborn as sns

from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
import sklearn.model_selection as model_selection
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.metrics import classification_report
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
import tensorflow as tf

from collections import Counter
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
import warnings
warnings.simplefilter(action='ignore')

# %%
# Clears file to re-generate every time this notebook is run
# If this is not run each model result will be appended onto the existing file
! rm -r ../output/dev_results

# %% [markdown]
# ### Import csv features which were extracted from earlier Data PreProcessing notebook

# %%
X_train_w = pd.read_csv('../data/X_train_w.csv',index_col = 0)
X_train_m = pd.read_csv('../data/X_train_m.csv',index_col = 0)
X_train_c = pd.read_csv('../data/X_train_c.csv',index_col = 0)
X_test_w = pd.read_csv('../data/X_test_w.csv',index_col = 0)
X_test_m = pd.read_csv('../data/X_test_m.csv',index_col = 0)
X_test_c = pd.read_csv('../data/X_test_c.csv',index_col = 0)
y_train_w = pd.read_csv('../data/y_train_w.csv',index_col = 0)
y_train_m = pd.read_csv('../data/y_train_m.csv',index_col = 0)
y_train_c = pd.read_csv('../data/y_train_c.csv',index_col = 0)
y_test_w = pd.read_csv('../data/y_test_w.csv',index_col = 0)
y_test_m = pd.read_csv('../data/y_test_m.csv',index_col = 0)
y_test_c = pd.read_csv('../data/y_test_c.csv',index_col = 0)

# %%
print('Shape of Wav Data :')
print( X_train_w.shape, y_train_w.shape , X_test_w.shape , y_test_w.shape)
print('Shape of MIDI Data :')
print( X_train_m.shape, y_train_m.shape , X_test_m.shape , y_test_m.shape)
print('Shape of Combined Wav and MIDI Data :')
print( X_train_c.shape, y_train_c.shape , X_test_c.shape , y_test_c.shape)
# Out:
# Shape of Wav Data :
# (263, 167) (263, 1) (66, 167) (66, 1)
# Shape of MIDI Data :
# (263, 10) (263, 1) (66, 10) (66, 1)
# Shape of Combined Wav and MIDI Data :
# (263, 176) (263, 1) (66, 176) (66, 1)

# %% [markdown]
# # Models

# %% [markdown]
# ## 1. Logistic Regression

# %% [markdown]
# ### 1.1 Spectral (WAV) Data Only

# %% [markdown]
# #### 1.1.1 Baseline model

# %%
#Create Baseline Logistic Model
lr = LogisticRegression(C = 0.5, solver='liblinear', multi_class='auto')
lr.fit(np.array(X_train_w), np.array(y_train_w))
#cross validation with 5 fold on training data
scores = cross_val_score(estimator = lr, X=X_train_w, y=y_train_w.values.ravel(), cv=5, n_jobs=1, scoring='f1_weighted')
# output (printed to text file and displayed within notebook)
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 1.1.1\n'
model_type = 'Logistic Regression Baseline Model (wav data only)\n'
model_scores = f'CV Scores: {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# Out:
# Model #: 1.1.1
#  Logistic Regression Baseline Model (wav data only)
#  CV Scores: [0.86865022 0.88865687 0.86914011 0.86424772 0.93960864]
#  CV Average and standard deviation: 0.8860607118376898 +/- 0.028069053819395614

# %% [markdown]
# #### 1.1.2 PCA components

# %%
#all possible values of principal components can go up to the number of features
all_possible_k = range(1,len(X_train_w.columns))

# Create empty list to store fraction of total variance
all_possible_k_variance = []

# Write for loop to try k values for PCA
for i in all_possible_k:
    pca = PCA(n_components = i)
    pca.fit(X_train_w)
    train_pca = pca.transform(X_train_w)
    
    #Append fractions of explained total variance
    all_possible_k_variance.append(np.sum(pca.explained_variance_ratio_))
    
    #Logistic Regression Model with PCA
    lr = LogisticRegression(C = 0.5, max_iter = 100,solver='liblinear', multi_class='auto')
    lr.fit(train_pca,y_train_w)

plt.plot(all_possible_k[0:8], all_possible_k_variance[0:8])
for x,y in zip(all_possible_k,all_possible_k_variance):
    print("Explained Variance with {} Principal Components: {:.2%}".format(x,y))

# show lineplot of fraction of total variance vs. number of principal components, for all possible numbers of principal components.
# Add title and axis names
# save plot to output/plots folder
plt.title('Number of PCA Components vs Explained Variance Fraction ')
plt.xlabel('Number of PCA Components')
plt.ylabel('Explained Variance')
plt.savefig('../output/plots/1.1.2_PCA_Components.png')
plt.show()

pca = PCA(n_components = 5)
pca.fit(X_train_w)
X_train_pca = pca.transform(X_train_w)

lr = LogisticRegression(C = 0.5, max_iter = 100,solver='liblinear', multi_class='auto')
lr.fit(X_train_pca,y_train_w)
scores = cross_val_score(estimator = lr, X=X_train_pca, y=y_train_w.values.ravel(), cv=5, n_jobs=1,  scoring='f1_weighted')
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 1.1.2\n'
model_type = 'Logistic Regression with PCA (wav data only)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# Out:
# Explained Variance with 1 Principal Components: 84.97%
# Explained Variance with 2 Principal Components: 94.32%
# Explained Variance with 3 Principal Components: 96.57%
# Explained Variance with 4 Principal Components: 97.40%
# Explained Variance with 5 Principal Components: 98.08%
# Explained Variance with 6 Principal Components: 98.42%
# Explained Variance with 7 Principal Components: 98.69%
# Explained Variance with 8 Principal Components: 98.95%
# Explained Variance with 9 Principal Components: 99.14%
# Explained Variance with 10 Principal Components: 99.27%
# Explained Variance with 11 Principal Components: 99.36%
# Explained Variance with 12 Principal Components: 99.43%
# Explained Variance with 13 Principal Components: 99.49%
# Explained Variance with 14 Principal Components: 99.55%
# Explained Variance with 15 Principal Components: 99.60%
# Explained Variance with 16 Principal Components: 99.64%
# Explained Variance with 17 Principal Components: 99.68%
# Explained Variance with 18 Principal Components: 99.71%
# Explained Variance with 19 Principal Components: 99.74%
# Explained Variance with 20 Principal Components: 99.77%
# Explained Variance with 21 Principal Components: 99.80%
# Explained Variance with 22 Principal Components: 99.82%
# Explained Variance with 23 Principal Components: 99.84%
# Explained Variance with 24 Principal Components: 99.85%
# Explained Variance with 25 Principal Components: 99.87%
# Explained Variance with 26 Principal Components: 99.88%
# Explained Variance with 27 Principal Components: 99.89%
# Explained Variance with 28 Principal Components: 99.91%
# Explained Variance with 29 Principal Components: 99.92%
# Explained Variance with 30 Principal Components: 99.92%
# Explained Variance with 31 Principal Components: 99.93%
# Explained Variance with 32 Principal Components: 99.94%
# Explained Variance with 33 Principal Components: 99.95%
# Explained Variance with 34 Principal Components: 99.95%
# Explained Variance with 35 Principal Components: 99.96%
# Explained Variance with 36 Principal Components: 99.96%
# Explained Variance with 37 Principal Components: 99.97%
# Explained Variance with 38 Principal Components: 99.97%
# Explained Variance with 39 Principal Components: 99.98%
# Explained Variance with 40 Principal Components: 99.98%
# Explained Variance with 41 Principal Components: 99.98%
# Explained Variance with 42 Principal Components: 99.98%
# Explained Variance with 43 Principal Components: 99.99%
# Explained Variance with 44 Principal Components: 99.99%
# Explained Variance with 45 Principal Components: 99.99%
# Explained Variance with 46 Principal Components: 99.99%
# Explained Variance with 47 Principal Components: 99.99%
# Explained Variance with 48 Principal Components: 99.99%
# Explained Variance with 49 Principal Components: 99.99%
# Explained Variance with 50 Principal Components: 100.00%
# Explained Variance with 51 Principal Components: 100.00%
# Explained Variance with 52 Principal Components: 100.00%
# Explained Variance with 53 Principal Components: 100.00%
# Explained Variance with 54 Principal Components: 100.00%
# Explained Variance with 55 Principal Components: 100.00%
# Explained Variance with 56 Principal Components: 100.00%
# Explained Variance with 57 Principal Components: 100.00%
# Explained Variance with 58 Principal Components: 100.00%
# Explained Variance with 59 Principal Components: 100.00%
# Explained Variance with 60 Principal Components: 100.00%
# Explained Variance with 61 Principal Components: 100.00%
# Explained Variance with 62 Principal Components: 100.00%
# Explained Variance with 63 Principal Components: 100.00%
# Explained Variance with 64 Principal Components: 100.00%
# Explained Variance with 65 Principal Components: 100.00%
# Explained Variance with 66 Principal Components: 100.00%
# Explained Variance with 67 Principal Components: 100.00%
# Explained Variance with 68 Principal Components: 100.00%
# Explained Variance with 69 Principal Components: 100.00%
# Explained Variance with 70 Principal Components: 100.00%
# Explained Variance with 71 Principal Components: 100.00%
# Explained Variance with 72 Principal Components: 100.00%
# Explained Variance with 73 Principal Components: 100.00%
# Explained Variance with 74 Principal Components: 100.00%
# Explained Variance with 75 Principal Components: 100.00%
# Explained Variance with 76 Principal Components: 100.00%
# Explained Variance with 77 Principal Components: 100.00%
# Explained Variance with 78 Principal Components: 100.00%
# Explained Variance with 79 Principal Components: 100.00%
# Explained Variance with 80 Principal Components: 100.00%
# Explained Variance with 81 Principal Components: 100.00%
# Explained Variance with 82 Principal Components: 100.00%
# Explained Variance with 83 Principal Components: 100.00%
# Explained Variance with 84 Principal Components: 100.00%
# Explained Variance with 85 Principal Components: 100.00%
# Explained Variance with 86 Principal Components: 100.00%
# Explained Variance with 87 Principal Components: 100.00%
# Explained Variance with 88 Principal Components: 100.00%
# Explained Variance with 89 Principal Components: 100.00%
# Explained Variance with 90 Principal Components: 100.00%
# Explained Variance with 91 Principal Components: 100.00%
# Explained Variance with 92 Principal Components: 100.00%
# Explained Variance with 93 Principal Components: 100.00%
# Explained Variance with 94 Principal Components: 100.00%
# Explained Variance with 95 Principal Components: 100.00%
# Explained Variance with 96 Principal Components: 100.00%
# Explained Variance with 97 Principal Components: 100.00%
# Explained Variance with 98 Principal Components: 100.00%
# Explained Variance with 99 Principal Components: 100.00%
# Explained Variance with 100 Principal Components: 100.00%
# Explained Variance with 101 Principal Components: 100.00%
# Explained Variance with 102 Principal Components: 100.00%
# Explained Variance with 103 Principal Components: 100.00%
# Explained Variance with 104 Principal Components: 100.00%
# Explained Variance with 105 Principal Components: 100.00%
# Explained Variance with 106 Principal Components: 100.00%
# Explained Variance with 107 Principal Components: 100.00%
# Explained Variance with 108 Principal Components: 100.00%
# Explained Variance with 109 Principal Components: 100.00%
# Explained Variance with 110 Principal Components: 100.00%
# Explained Variance with 111 Principal Components: 100.00%
# Explained Variance with 112 Principal Components: 100.00%
# Explained Variance with 113 Principal Components: 100.00%
# Explained Variance with 114 Principal Components: 100.00%
# Explained Variance with 115 Principal Components: 100.00%
# Explained Variance with 116 Principal Components: 100.00%
# Explained Variance with 117 Principal Components: 100.00%
# Explained Variance with 118 Principal Components: 100.00%
# Explained Variance with 119 Principal Components: 100.00%
# Explained Variance with 120 Principal Components: 100.00%
# Explained Variance with 121 Principal Components: 100.00%
# Explained Variance with 122 Principal Components: 100.00%
# Explained Variance with 123 Principal Components: 100.00%
# Explained Variance with 124 Principal Components: 100.00%
# Explained Variance with 125 Principal Components: 100.00%
# Explained Variance with 126 Principal Components: 100.00%
# Explained Variance with 127 Principal Components: 100.00%
# Explained Variance with 128 Principal Components: 100.00%
# Explained Variance with 129 Principal Components: 100.00%
# Explained Variance with 130 Principal Components: 100.00%
# Explained Variance with 131 Principal Components: 100.00%
# Explained Variance with 132 Principal Components: 100.00%
# Explained Variance with 133 Principal Components: 100.00%
# Explained Variance with 134 Principal Components: 100.00%
# Explained Variance with 135 Principal Components: 100.00%
# Explained Variance with 136 Principal Components: 100.00%
# Explained Variance with 137 Principal Components: 100.00%
# Explained Variance with 138 Principal Components: 100.00%
# Explained Variance with 139 Principal Components: 100.00%
# Explained Variance with 140 Principal Components: 100.00%
# Explained Variance with 141 Principal Components: 100.00%
# Explained Variance with 142 Principal Components: 100.00%
# Explained Variance with 143 Principal Components: 100.00%
# Explained Variance with 144 Principal Components: 100.00%
# Explained Variance with 145 Principal Components: 100.00%
# Explained Variance with 146 Principal Components: 100.00%
# Explained Variance with 147 Principal Components: 100.00%
# Explained Variance with 148 Principal Components: 100.00%
# Explained Variance with 149 Principal Components: 100.00%
# Explained Variance with 150 Principal Components: 100.00%
# Explained Variance with 151 Principal Components: 100.00%
# Explained Variance with 152 Principal Components: 100.00%
# Explained Variance with 153 Principal Components: 100.00%
# Explained Variance with 154 Principal Components: 100.00%
# Explained Variance with 155 Principal Components: 100.00%
# Explained Variance with 156 Principal Components: 100.00%
# Explained Variance with 157 Principal Components: 100.00%
# Explained Variance with 158 Principal Components: 100.00%
# Explained Variance with 159 Principal Components: 100.00%
# Explained Variance with 160 Principal Components: 100.00%
# Explained Variance with 161 Principal Components: 100.00%
# Explained Variance with 162 Principal Components: 100.00%
# Explained Variance with 163 Principal Components: 100.00%
# Explained Variance with 164 Principal Components: 100.00%
# Explained Variance with 165 Principal Components: 100.00%
# Explained Variance with 166 Principal Components: 100.00%
# Model #: 1.1.2
#  Logistic Regression with PCA (wav data only)
#  CV Scores [0.56137119 0.63606575 0.56957999 0.6098125  0.58377868]
#  CV Average and standard deviation: 0.592121620802015 +/- 0.027449490564249102

# %% [markdown]
# ### 1.2 MIDI Data Only

# %% [markdown]
# #### 1.2.1 Baseline model

# %%
lr = LogisticRegression(C = 0.5, solver='liblinear', multi_class='auto')
lr.fit(np.array(X_train_m), np.array(y_train_m))
scores = cross_val_score(estimator = lr, X=X_train_m, y=y_train_m, cv=5, n_jobs=1,  scoring='f1_weighted')
# save and print output
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 1.2.1\n'
model_type = 'Logistic Regression Baseline Model (midi data only)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# Out:
# Model #: 1.2.1
#  Logistic Regression Baseline Model (midi data only)
#  CV Scores [0.60700212 0.69156365 0.64708525 0.61101106 0.69564979]
#  CV Average and standard deviation: 0.6504623758731147 +/- 0.037915226747904124

# %% [markdown]
# #### 1.2.2 PCA components

# %%
#all possible values of principal components can go up to the number of features
all_possible_k = range(1,len(X_train_m.columns))

# Create empty list to store fraction of total variance
all_possible_k_variance = []

# Write for loop to try k values for PCA
for i in all_possible_k:
    pca = PCA(n_components = i)
    pca.fit(X_train_m)
    train_pca = pca.transform(X_train_m)
    
    #Append fractions of explained total variance
    all_possible_k_variance.append(np.sum(pca.explained_variance_ratio_))
    
    #Logistic Regression Model with PCA
    lr = LogisticRegression(C = 0.5, max_iter = 100,solver='liblinear', multi_class='auto')
    lr.fit(train_pca,y_train_w)

plt.plot(all_possible_k[0:8], all_possible_k_variance[0:8])
print(all_possible_k_variance[0:8])

# show lineplot of fraction of total variance vs. number of principal components, for all possible numbers of principal components.
# Add title and axis names
# save plot
plt.title('Number of PCA Components vs Explained Variance Fraction ')
plt.xlabel('Number of PCA Components')
plt.ylabel('Explained Variance')
plt.savefig('../output/plots/1.2.2 PCA Components.png')
plt.show()

pca = PCA(n_components = 5)
pca.fit(X_train_m)
X_train_pca = pca.transform(X_train_m)

lr = LogisticRegression(C = 0.5, max_iter = 100,solver='liblinear', multi_class='auto')
lr.fit(X_train_pca,y_train_w)
scores = cross_val_score(estimator = lr, X=X_train_pca, y=y_train_w, cv=5, n_jobs=1,  scoring='f1_weighted')
# save and print output
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 1.2.2\n'
model_type = 'Logistic Regression with PCA (midi data only)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# Out:
# [0.8472469251566341, 0.9999994828649595, 0.9999999950423859, 0.9999999979326265, 0.9999999995373897, 0.9999999998110076, 0.9999999999006716, 0.9999999999631858]
# Model #: 1.2.2
#  Logistic Regression with PCA (midi data only)
#  CV Scores [0.30237059 0.30629748 0.13595105 0.31218781 0.31218781]
#  CV Average and standard deviation: 0.27379894625177637 +/- 0.06902455626074773

# %% [markdown]
# ### 1.3 Combined Data (WAV & MIDI)

# %% [markdown]
# #### 1.3.1 Baseline model

# %%
lr = LogisticRegression(C = 0.5, solver='liblinear', multi_class='auto')
lr.fit(np.array(X_train_c), np.array(y_train_c))
scores = cross_val_score(estimator = lr, X=X_train_c, y=y_train_c, cv=5, n_jobs=1,  scoring='f1_weighted')
# save and print output
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 1.3.1\n'
model_type = 'Logistic Regression Baseline Model (combined midi and wav data)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# Out:
# Model #: 1.3.1
#  Logistic Regression Baseline Model (combined midi and wav data)
#  CV Scores [0.75553733 0.80632889 0.87739767 0.76783724 0.91410795]
#  CV Average and standard deviation: 0.8242418150180602 +/- 0.06184516768275534

# %% [markdown]
# #### 1.3.2 PCA components

# %%
#all possible values of principal components can go up to the number of features
all_possible_k = range(1,len(X_train_c.columns))

# Create empty list to store fraction of total variance
all_possible_k_variance = []

# Write for loop to try k values for PCA
for i in all_possible_k:
    pca = PCA(n_components = i)
    pca.fit(X_train_c)
    train_pca = pca.transform(X_train_c)
    
    #Append fractions of explained total variance
    all_possible_k_variance.append(np.sum(pca.explained_variance_ratio_))
    
    #Logistic Regression Model with PCA
    lr = LogisticRegression(C = 0.5, max_iter = 100,solver='liblinear', multi_class='auto')
    lr.fit(train_pca,y_train_w)

plt.plot(all_possible_k[0:8], all_possible_k_variance[0:8])
print(all_possible_k_variance[0:8])

# show lineplot of fraction of total variance vs. number of principal components, for all possible numbers of principal components.
# Add title and axis names
# save plot
plt.title('Number of PCA Components vs Explained Variance Fraction ')
plt.xlabel('Number of PCA Components')
plt.ylabel('Explained Variance')
plt.savefig('../output/plots/1.3.2 PCA Components.png')
plt.show()

pca = PCA(n_components = 5)
pca.fit(X_train_c)
X_train_pca = pca.transform(X_train_c)

lr = LogisticRegression(C = 0.5, max_iter = 100,solver='liblinear', multi_class='auto')
lr.fit(X_train_pca,y_train_c)
scores = cross_val_score(estimator = lr, X=X_train_pca, y=y_train_w, cv=5, n_jobs=1,  scoring='f1_weighted')
# save and print output
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 1.3.2\n'
model_type = 'Logistic Regression with PCA (combined midi and wav data)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# Out:
# [0.8472467564714535, 0.9999993006005323, 0.9999998191050802, 0.9999999250480672, 0.9999999510448121, 0.9999999628415001, 0.9999999703478009, 0.9999999753281146]
# Model #: 1.3.2
#  Logistic Regression with PCA (combined midi and wav data)
#  CV Scores [0.30237059 0.28550149 0.28550149 0.31218781 0.30769231]
#  CV Average and standard deviation: 0.2986507368831103 +/- 0.011177165052539052

# %% [markdown]
# ## 2. Naive Bayes

# %% [markdown]
# ### 2.1 Spectral (WAV) Data Only

# %% [markdown]
# #### 2.1.1 Baseline model

# %%
gnb = GaussianNB()
scores = cross_val_score(estimator = gnb, X=X_train_w, y=y_train_w, cv=5, n_jobs=1, scoring='f1_weighted')
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 2.1.1\n'
model_type = 'Naive Bayes Baseline Model (wav data only)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# Out:
# Model #: 2.1.1
#  Naive Bayes Baseline Model (wav data only)
#  CV Scores [0.66838433 0.70943396 0.68252735 0.65248458 0.62065018]
#  CV Average and standard deviation: 0.666696081533981 +/- 0.029672200294891975

# %% [markdown]
# ### 2.2 MIDI Data Only

# %% [markdown]
# #### 2.2.1 Baseline model

# %%
gnb = GaussianNB()
scores = cross_val_score(estimator = gnb, X=X_train_m, y=y_train_m, cv=5, n_jobs=1, scoring='f1_weighted')
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 2.2.1\n'
model_type = 'Naive Bayes Baseline Model (midi data only)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# Out:
# Model #: 2.2.1
#  Naive Bayes Baseline Model (midi data only)
#  CV Scores [0.58334988 0.34132445 0.69291669 0.56844181 0.75836225]
#  CV Average and standard deviation: 0.588879019523674 +/- 0.1423235166205818

# %% [markdown]
# ### 2.3 Combined Data (WAV & MIDI)

# %% [markdown]
# #### 2.3.1 Baseline model

# %%
gnb = GaussianNB()
scores = cross_val_score(estimator = gnb, X=X_train_c, y=y_train_c, cv=5, n_jobs=1, scoring='f1_weighted')
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 2.3.1\n'
model_type = 'Naive Bayes Baseline Model (combined midi and wav data)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# Out:
# Model #: 2.3.1
#  Naive Bayes Baseline Model (combined midi and wav data)
#  CV Scores [0.73519671 0.76483122 0.76776437 0.73039216 0.71722722]
#  CV Average and standard deviation: 0.7430823327079817 +/- 0.01986920881385733

# %% [markdown]
# ## 3. Decision Tree

# %% [markdown]
# ### 3.1 Spectral (WAV) Data Only

# %% [markdown]
# #### 3.1.1 Baseline model

# %%
dt = DecisionTreeClassifier()
scores = cross_val_score(estimator = dt, X=X_train_w, y=y_train_w, cv=5, n_jobs=1, scoring='f1_weighted')
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 3.1.1\n'
model_type = 'Decision Tree Baseline Model (wav data only)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# Out:
# Model #: 3.1.1
#  Decision Tree Baseline Model (wav data only)
#  CV Scores [0.69790951 0.75107101 0.71948496 0.74836542 0.6687797 ]
#  CV Average and standard deviation: 0.7171221193876437 +/- 0.031113879173321587

# %% [markdown]
# ### 3.2 MIDI Data Only

# %% [markdown]
# #### 3.2.1 Baseline model

# %%
dt = DecisionTreeClassifier()
scores = cross_val_score(estimator = dt, X=X_train_m, y=y_train_m, cv=5, n_jobs=1, scoring='f1_weighted')
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 3.2.1\n'
model_type = 'Decision Tree Baseline Model (midi data only)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# Out:
# Model #: 3.2.1
#  Decision Tree Baseline Model (midi data only)
#  CV Scores [0.83832222 0.77617764 0.82224429 0.92220937 0.85224657]
#  CV Average and standard deviation: 0.8422400175408946 +/- 0.04748609092236858

# %% [markdown]
# ### 3.3 Combined Data (WAV & MIDI)

# %% [markdown]
# #### 3.3.1 Baseline model

# %%
dt = DecisionTreeClassifier()
scores = cross_val_score(estimator = dt, X=X_train_c, y=y_train_c, cv=5, n_jobs=1, scoring='f1_weighted')
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 3.3.1\n'
model_type = 'Decision Tree Baseline Model (combined midi and wav data)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# Out:
# Model #: 3.3.1
#  Decision Tree Baseline Model (combined midi and wav data)
#  CV Scores [0.75345912 0.77927473 0.77035569 0.89015809 0.89918415]
#  CV Average and standard deviation: 0.8184863548825062 +/- 0.06281978221207221

# %% [markdown]
# ## 4. Random Forest

# %% [markdown]
# ### 4.1 Spectral (WAV) Data Only

# %% [markdown]
# #### 4.1.1 Baseline model

# %%
rf = RandomForestClassifier()
rf.fit(X_train_w, y_train_w)
scores = cross_val_score(estimator = rf, X=X_train_w, y=y_train_w, cv=5, n_jobs=1, scoring='f1_weighted')
# save and print output
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 4.1.1\n'
model_type = 'Random Forest Baseline Model (wav data only)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)

# plots feature importants and saves plot
feat_importances = pd.Series(rf.feature_importances_, index=X_train_w.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.title('Feature Importance')
plt.ylabel('Features')
plt.xlabel('Gini Importance')
plt.tight_layout()
plt.savefig('../output/plots/4.1.1 Feature Importance.png')
# Out:
# Model #: 4.1.1
#  Random Forest Baseline Model (wav data only)
#  CV Scores [0.81441232 0.82444627 0.69997457 0.83938746 0.74238624]
#  CV Average and standard deviation: 0.7841213723199217 +/- 0.053703789988411084

# %% [markdown]
# #### 4.1.2 Sampling (SMOTE), no hyperparameter tuning

# %%
# todo: I think we need to re-import the data for this cell, if this is run multiple times then y_train_w gets overwritten
y_train_w = pd.read_csv('../data/y_train_w.csv',index_col = 0)
# Visualize the target variable
g = sns.countplot(y_train_w['ensemble'])
g.set_xticklabels(['Horn Piano Trio',
'Solo Piano',
'Piano Trio',
'Viola Quintet',
'String Quartet',
'Clarinet Quintet',
'Pairs Clarinet-Horn-Bassoon',
'Wind Quintet',
'Accompanied Cello',
'Piano Quintet',
'Wind and Strings Octet',
'String Sextet',
'Piano Quartet',
'Accompanied Clarinet',
'Solo Violin',
'Solo Flute',
'Solo Cello',
'Violin and Harpsichord',
'Clarinet-Cello-Piano Trio',
'Accompanied Violin'],rotation_mode='anchor',rotation=45, ha='right')
plt.title('Ensemble counts (pre-SMOTE resampling)')
plt.tight_layout()
plt.savefig('../output/plots/4.1.2 Pre-SMOTE Sample Counts.png')
plt.show()

#Drop any ensemble types with counts below 6. This because Expected n_neighbors <= n_samples,  
#but n_samples = 3, n_neighbors = 6
counts = y_train_w['ensemble'].value_counts()
X_train_w = X_train_w[~y_train_w['ensemble'].isin(counts[counts < 6].index)]
y_train_w = y_train_w[~y_train_w['ensemble'].isin(counts[counts < 6].index)]
print(X_train_w.shape, y_train_w.shape)

#Synthetic Minority Oversampling Technique (SMOTE): This technique generates synthetic data for the minority class.

#SMOTE (Synthetic Minority Oversampling Technique) works by randomly picking a point from the minority class 
#and computing the k-nearest neighbors for this point. The synthetic points are added between the chosen point 
#and its neighbors.


# Fit and apply the transform
X_SMOTE_w, y_SMOTE_w = SMOTE(random_state=101).fit_resample(X_train_w, y_train_w)

print('Original dataset shape', Counter(y_train_w.values.ravel()))
print('Resample dataset shape', Counter(y_SMOTE_w.values.ravel()))

# Visualize the target variable
g = sns.countplot(y_SMOTE_w['ensemble'])
g.set_xticklabels([
'Solo Piano', 
'Piano Trio',
'String Quartet',
'Wind Quintet',
'Accompanied Cello',
'Piano Quartet',
'Solo Violin',
'Solo Cello',
'Accompanied Violin'],rotation_mode='anchor',rotation=45, ha='right')
plt.title('Ensemble counts after SMOTE resampling)')
plt.tight_layout()
plt.savefig('../output/plots/4.1.2 Post-SMOTE Sample Counts.png')
plt.show()

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=1)
rf.fit(X_SMOTE_w, y_SMOTE_w)
scores = cross_val_score(estimator = rf, X=X_SMOTE_w, y=y_SMOTE_w, cv=5, n_jobs=1, scoring='f1_weighted')
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 4.1.2\n'
model_type = 'Random Forest with SMOTE and no hyperparameter tuning (wav data only)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
#Default parameters:
    #n_estimatorsint, default=100
    #max_features{“auto”, “sqrt”, “log2”}, int or float, default=”auto”
    #min_samples_splitint or float, default=2
fig, ax = plt.subplots(figsize=(8,4))
feat_importances = pd.Series(rf.feature_importances_, index=X_SMOTE_w.columns)
ax = feat_importances.nlargest(10).plot(kind='barh')
ax.set_xlabel('Gini Importance')
ax.set_ylabel('Features')
ax.set_title('Feature Importance')
plt.tight_layout()
plt.savefig('../output/plots/4.1.2 Feature Importance.png')
plt.show()
# Out:
# (231, 167) (231, 1)
# Original dataset shape Counter({1: 125, 4: 46, 19: 18, 16: 10, 14: 7, 7: 7, 12: 6, 8: 6, 2: 6})
# Resample dataset shape Counter({19: 125, 1: 125, 12: 125, 14: 125, 16: 125, 4: 125, 7: 125, 8: 125, 2: 125})
# Model #: 4.1.2
#  Random Forest with SMOTE and no hyperparameter tuning (wav data only)
#  CV Scores [0.99555378 0.98661849 0.99555378 1.         1.        ]
#  CV Average and standard deviation: 0.9955452094750207 +/- 0.004886240410560162

# %% [markdown]
# ### 4.2 MIDI Data Only

# %% [markdown]
# #### 4.2.1 Baseline model

# %%
rf = RandomForestClassifier()
rf.fit(X_train_m, y_train_m)
scores = cross_val_score(estimator = rf, X=X_train_m, y=y_train_m, cv=5, n_jobs=1, scoring='f1_weighted')
# print and save output
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 4.2.1\n'
model_type = 'Random Forest Baseline midel (midi data only)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)

feat_importances = pd.Series(rf.feature_importances_, index=X_train_m.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.title('Feature Importance')
plt.xlabel('Gini Importance')
plt.ylabel('Features')
plt.tight_layout()
plt.savefig('../output/plots/4.2.1 Feature Importance.png')
# Out:
# Model #: 4.2.1
#  Random Forest Baseline midel (midi data only)
#  CV Scores [0.79806828 0.79609401 0.87785501 0.89081197 0.87619752]
#  CV Average and standard deviation: 0.8478053587319494 +/- 0.04172889952252854

# %% [markdown]
# #### Observation : "midi_nunique instruments" seems to be the variable with the strongest explanatory power with 40% variance explained. We have concerns about evaluating performance using a feature set that includes this variable because in practice we typically would not have manually labelled data.

# %% [markdown]
# #### 4.2.2 Sampling (SMOTE), no hyperparameter tuning

# %%
#Drop any ensemble types with counts below 6. This because Expected n_neighbors <= n_samples,  
#but n_samples = 3, n_neighbors = 6
counts = y_train_m['ensemble'].value_counts()
X_train_m = X_train_m[~y_train_m['ensemble'].isin(counts[counts < 6].index)]
y_train_m = y_train_m[~y_train_m['ensemble'].isin(counts[counts < 6].index)]
print(X_train_m.shape, y_train_m.shape)

#Synthetic Minority Oversampling Technique (SMOTE): This technique generates synthetic data for the minority class.

#SMOTE (Synthetic Minority Oversampling Technique) works by randomly picking a point from the minority class 
#and computing the k-nearest neighbors for this point. The synthetic points are added between the chosen point 
#and its neighbors.

# Fit and apply the transform
X_SMOTE_m, y_SMOTE_m = SMOTE(random_state=101).fit_resample(X_train_m, y_train_m)

print('Original dataset shape', Counter(y_train_m.values.ravel()))
print('Resample dataset shape', Counter(y_SMOTE_m.values.ravel()))

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=1)
rf.fit(X_SMOTE_m, y_SMOTE_m)
scores = cross_val_score(estimator = rf, X=X_SMOTE_m, y=y_SMOTE_m, cv=5, n_jobs=1, scoring='f1_weighted')
# Save and print output
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 4.2.2\n'
model_type = 'Random Forest with SMOTE and no hyperparameter tuning (midi data only)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
#Default parameters:
    #n_estimatorsint, default=100
    #max_features{“auto”, “sqrt”, “log2”}, int or float, default=”auto”
    #min_samples_splitint or float, default=2

# save and print plot 
feat_importances = pd.Series(rf.feature_importances_, index=X_train_m.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.title('Feature Importance')
plt.ylabel('Features')
plt.xlabel('Gini Importance')
plt.tight_layout()
plt.savefig('../output/plots/4.2.2 Feature Importance.png')
# Out:
# (231, 10) (231, 1)
# Original dataset shape Counter({1: 125, 4: 46, 19: 18, 16: 10, 7: 7, 14: 7, 2: 6, 8: 6, 12: 6})
# Resample dataset shape Counter({1: 125, 2: 125, 4: 125, 7: 125, 8: 125, 12: 125, 14: 125, 16: 125, 19: 125})
# Model #: 4.2.2
#  Random Forest with SMOTE and no hyperparameter tuning (midi data only)
#  CV Scores [0.99555378 0.99555378 0.99555378 0.99555378 0.98661849]
#  CV Average and standard deviation: 0.9937667203015735 +/- 0.0035741135296171846

# %% [markdown]
# ### 4.3 Combined Data (WAV & MIDI)

# %% [markdown]
# #### 4.3.1 Baseline model

# %%
rf = RandomForestClassifier()
rf.fit(X_train_c, y_train_c)
scores = cross_val_score(estimator = rf, X=X_train_c, y=y_train_c, cv=5, n_jobs=1, scoring='f1_weighted')
# prints and saves output
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 4.3.1\n'
model_type = 'Random Forest Baseline Model (midi and wav data)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# print and save plot
feat_importances = pd.Series(rf.feature_importances_, index=X_train_c.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.title('Feature Importance')
plt.xlabel('Gini Importance')
plt.ylabel('Features')
plt.tight_layout()
plt.savefig('../output/plots/4.3.1 Feature Importance.png')
# Out:
# Model #: 4.3.1
#  Random Forest Baseline Model (midi and wav data)
#  CV Scores [0.70157176 0.87053701 0.86244621 0.8538865  0.89176529]
#  CV Average and standard deviation: 0.8360413520927323 +/- 0.0684000660398279

# %% [markdown]
# ####  Observation : We can see here that the midi_nunique_instruments variable is still explaining far more variance in our dataset than any spectral feature. This indicates its strong predictive power in comparison.We have concerns about evaluating performance using a feature set that includes this variable because in practice we typically would not have manually labelled data.

# %% [markdown]
# #### 4.3.2 Sampling (SMOTE), no hyperparameter tuning

# %%
#Drop any ensemble types with counts below 6. This because Expected n_neighbors <= n_samples,  
#but n_samples = 3, n_neighbors = 6
counts = y_train_c['ensemble'].value_counts()
X_train_c = X_train_c[~y_train_c['ensemble'].isin(counts[counts < 6].index)]
y_train_c = y_train_c[~y_train_c['ensemble'].isin(counts[counts < 6].index)]
print(X_train_c.shape, y_train_c.shape)

#Synthetic Minority Oversampling Technique (SMOTE): This technique generates synthetic data for the minority class.

#SMOTE (Synthetic Minority Oversampling Technique) works by randomly picking a point from the minority class 
#and computing the k-nearest neighbors for this point. The synthetic points are added between the chosen point 
#and its neighbors.

X_SMOTE_c, y_SMOTE_c = SMOTE(random_state=101).fit_resample(X_train_c, y_train_c)

print('Original dataset shape', Counter(y_train_c.values.ravel()))
print('Resample dataset shape', Counter(y_SMOTE_c.values.ravel()))


from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=1)
rf.fit(X_SMOTE_c, y_SMOTE_c)
scores = cross_val_score(estimator = rf, X=X_SMOTE_c, y=y_SMOTE_c, cv=5, n_jobs=1, scoring='f1_weighted')
# prints and saves output
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 4.3.2\n'
model_type = 'Random Forest with SMOTE (midi and wave data)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
#Default parameters:
    #n_estimatorsint, default=100
    #max_features{“auto”, “sqrt”, “log2”}, int or float, default=”auto”
    #min_samples_splitint or float, default=2
    
feat_importances = pd.Series(rf.feature_importances_, index=X_SMOTE_c.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.title('Feature Importance')
plt.xlabel('Gini Importance')
plt.ylabel('Features')
plt.tight_layout()
plt.savefig('../output/plots/4.3.2 Feature Importance.png')
# Out:
# (231, 176) (231, 1)
# Original dataset shape Counter({1: 125, 4: 46, 19: 18, 16: 10, 7: 7, 14: 7, 2: 6, 8: 6, 12: 6})
# Resample dataset shape Counter({1: 125, 2: 125, 4: 125, 7: 125, 8: 125, 12: 125, 16: 125, 14: 125, 19: 125})
# Model #: 4.3.2
#  Random Forest with SMOTE (midi and wave data)
#  CV Scores [0.98681349 1.         0.98661849 0.99109687 1.        ]
#  CV Average and standard deviation: 0.9929057695674659 +/- 0.006009560297427548

# %% [markdown]
# #### Observation :
#
# - Midi_min_note variable also has strong predictive power. Certain ensembles will have instruments that allow for lower notes to be played so the lowest note would probably be a good predictor of the ensemble.
#
# - Midi_nunique_note is important because ensembles composed of instruments with larger ranges will typically have a higher possibility of playing unique notes due to their unique access to notes that other ensembles might not have access to.

# %% [markdown]
# ## 5. SVM

# %% [markdown]
# ### 5.1 Spectral (WAV) Data Only

# %% [markdown]
# #### 5.1.1 Baseline model

# %%
#Create baseline SVM model with Spectral Data

svm = make_pipeline(SVC())
svm.fit(X_train_w, y_train_w.values.ravel())

#Apply 5 fold cross validation scoring to make sure results are reliable

scores = cross_val_score(estimator = svm, X=X_train_w, y=y_train_w.values.ravel(), cv=5,n_jobs=1, scoring='f1_weighted')
# prints and saves output
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 5.1.1\n'
model_type = 'SVM Baseline Model (wav data only)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# Out:
# Model #: 5.1.1
#  SVM Baseline Model (wav data only)
#  CV Scores [0.4500337  0.57625949 0.546875   0.56943937 0.56943937]
#  CV Average and standard deviation: 0.5424093850341674 +/- 0.0472446385868813

# %% [markdown]
# #### 5.1.2 Hyperparameter tuning

# %%
#Find best hyperparameters
param_grid = {'C': np.logspace(-4, 4, 20), 
              'gamma': np.logspace(-3, 2, 6),                     
              'kernel': ['linear','rbf','poly']} 
  
grid = GridSearchCV(SVC(), param_grid, cv=5)
  
# fitting the model for grid search
grid.fit(X_train_w, y_train_w.values.ravel())

print(grid.best_params_)


#Create Model with best hyperparameters

svm = make_pipeline(SVC(kernel=grid.best_params_['kernel'], C = grid.best_params_['C'] , gamma=grid.best_params_['gamma']))
svm.fit(X_train_w, y_train_w.values.ravel())

#Apply 5 fold cross validation scoring to make sure results are reliable

scores = cross_val_score(estimator = svm, X=X_train_w, y=y_train_w.values.ravel(), cv=5, n_jobs=1, scoring='f1_weighted')
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 5.1.2\n'
model_type = 'SVM with hyperparameter tuning (wav data only)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# Out:
# {'C': 0.0018329807108324356, 'gamma': 0.001, 'kernel': 'linear'}
# Model #: 5.1.2
#  SVM with hyperparameter tuning (wav data only)
#  CV Scores [0.86308037 0.89613527 0.91137238 0.90434783 0.9458653 ]
#  CV Average and standard deviation: 0.9041602276293361 +/- 0.02662073767043021

# %% [markdown]
# #### 5.1.3 Hyperparameter tuning, PCA

# %%
# Create list of K dimensions to test for PCA
p_comp = np.arange(1,25)


# Create empty list to store fraction of total variance
fraction_total_variance = []

# Write for loop to try k values for PCA
for i in p_comp:
    pca=PCA(n_components = i)
    pca.fit(X_train_w)
    train_pca_w = pca.transform(X_train_w)
    
    #Append fractions of explained total variance
    fraction_total_variance.append(np.sum(pca.explained_variance_ratio_))
    

#Show what fraction of the total variance in the training data is explained by the first k principal components, for k in [1, 2, 3, 4, 5, 10, 20, 30, 40, 50].    
variance_pca_df = pd.DataFrame({'Number of PCA Components':p_comp , 'Explained Fraction of Total Variance' :fraction_total_variance })

pd.set_option("display.max_rows", 500, "display.max_columns", 5, 'display.width', 1000)  
print(variance_pca_df)


#all possible values of k can go up to 166 i.e. one less than 167
all_possible_k = np.arange(1,167)

# Create empty list to store fraction of total variance
all_possible_k_variance = []

# Write for loop to try k values for PCA
for i in all_possible_k:
    pca=PCA(n_components = i)
    pca.fit(X_train_w)
    train_pca_w = pca.transform(X_train_w)
    
    #Append fractions of explained total variance
    all_possible_k_variance.append(np.sum(pca.explained_variance_ratio_))
    


plt.plot(all_possible_k, all_possible_k_variance)

# show lineplot of fraction of total variance vs. number of principal components, for all possible numbers of principal components.
# Add title and axis names
plt.title('Number of PCA Components vs Explained Variance Fraction ')
plt.xlabel('Number of PCA Components')
plt.ylabel('Explained Variance')
plt.savefig('../output/plots/5.1.3 PCA Plot.png')
plt.show()

#Perform PCA with 15 components
pca=PCA(n_components = 15)
pca.fit(X_train_w)
train_pca_w = pca.transform(X_train_w)

from sklearn.model_selection import GridSearchCV
  
# defining parameter range
param_grid = {'C': np.logspace(-4, 4, 20), 
              'gamma': np.logspace(-3, 2, 6),
              'kernel': ['linear','rbf','poly']} 
  
grid = GridSearchCV(SVC(), param_grid , cv=5)
  
# fitting the model for grid search
grid.fit(train_pca_w, y_train_w.values.ravel())

print(grid.best_params_)

#Create Model with best hyperparameters and PCA
svm = make_pipeline(SVC(kernel=grid.best_params_['kernel'], C = grid.best_params_['C'] , gamma=grid.best_params_['gamma']))
svm.fit(train_pca_w, y_train_w.values.ravel())


#Apply 5 fold cross validation scoring to make sure results are reliable
scores = cross_val_score(estimator = svm, X=train_pca_w, y=y_train_w.values.ravel(), cv=5, n_jobs=1, scoring='f1_weighted')
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 5.1.3\n'
model_type = 'SVM with hyperparameter tuning and PCA (wav data only)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# Out:
#     Number of PCA Components  Explained Fraction of Total Variance
# 0                          1                              0.861122
# 1                          2                              0.952000
# 2                          3                              0.972518
# 3                          4                              0.979182
# 4                          5                              0.985610
# 5                          6                              0.988322
# 6                          7                              0.990523
# 7                          8                              0.992320
# 8                          9                              0.993631
# 9                         10                              0.994591
# 10                        11                              0.995296
# 11                        12                              0.995868
# 12                        13                              0.996329
# 13                        14                              0.996715
# 14                        15                              0.997074
# 15                        16                              0.997391
# 16                        17                              0.997682
# 17                        18                              0.997941
# 18                        19                              0.998172
# 19                        20                              0.998381
# 20                        21                              0.998569
# 21                        22                              0.998742
# 22                        23                              0.998896
# 23                        24                              0.999029
# {'C': 0.0018329807108324356, 'gamma': 0.001, 'kernel': 'linear'}
# Model #: 5.1.3
#  SVM with hyperparameter tuning and PCA (wav data only)
#  CV Scores [0.88492926 0.86422578 0.87544813 0.91543052 0.91382869]
#  CV Average and standard deviation: 0.8907724766879015 +/- 0.020558763515073564

# %% [markdown]
# #### Observation : PCA does not reduce score but reduces number of features to just 15 principal components

# %% [markdown]
#  #### 5.1.4 Hyperparameter tuning, PCA, SMOTE

# %%
print("Before oversampling: ",Counter(y_train_w.values.ravel()))

#Drop any ensemble types with counts below 6
counts = y_train_w['ensemble'].value_counts()
X_train_w_smote = X_train_w[~y_train_w['ensemble'].isin(counts[counts < 6].index)]
y_train_w_smote = y_train_w[~y_train_w['ensemble'].isin(counts[counts < 6].index)]

#Now print data shape
print(X_train_w_smote.shape, y_train_w_smote.shape)

# fit and apply the transform
X_SMOTE, y_SMOTE = SMOTE().fit_resample(X_train_w_smote, y_train_w_smote.values.ravel())

# summarize class distribution
print("After oversampling: ",Counter(y_SMOTE))

# Create list of K dimensions to test for PCA
p_comp = np.arange(1,25)


# Create empty list to store fraction of total variance
fraction_total_variance = []

# Write for loop to try k values for PCA
for i in p_comp:
    pca=PCA(n_components = i)
    pca.fit(X_SMOTE)
    train_pca_w_smote = pca.transform(X_SMOTE)
    
    #Append fractions of explained total variance
    fraction_total_variance.append(np.sum(pca.explained_variance_ratio_))
    

#Show what fraction of the total variance in the training data is explained by the first k principal components, for k in [1, 2, 3, 4, 5, 10, 20, 30, 40, 50].    
variance_pca_df = pd.DataFrame({'Number of PCA Components':p_comp , 'Explained Fraction of Total Variance' :fraction_total_variance })

pd.set_option("display.max_rows", 500, "display.max_columns", 5, 'display.width', 1000)  
print(variance_pca_df)


#all possible values of k can go up to 166 i.e. one less than 167
all_possible_k = np.arange(1,167)

# Create empty list to store fraction of total variance
all_possible_k_variance = []

# Write for loop to try k values for PCA
for i in all_possible_k:
    pca=PCA(n_components = i)
    pca.fit(X_SMOTE)
    train_pca_w_smote = pca.transform(X_SMOTE)
    
    #Append fractions of explained total variance
    all_possible_k_variance.append(np.sum(pca.explained_variance_ratio_))
    

plt.plot(all_possible_k, all_possible_k_variance)

# show lineplot of fraction of total variance vs. number of principal components, for all possible numbers of principal components.
# Add title and axis names
plt.title('Number of PCA Components vs Explained Variance Fraction ')
plt.xlabel('Number of PCA Components')
plt.ylabel('Explained Variance')
plt.savefig('../output/plots/5.1.4 PCA Plot.png')
plt.show()

#Perform PCA with 15 components
pca=PCA(n_components = 15)
pca.fit(X_SMOTE)
train_pca_w_smote = pca.transform(X_SMOTE)


from sklearn.model_selection import GridSearchCV
  
# defining parameter range
param_grid = {'C': np.logspace(-4, 4, 20), 
              'gamma': np.logspace(-3, 2, 6),
              'kernel': ['linear','rbf','poly']} 
  
grid = GridSearchCV(SVC(), param_grid , cv=5)
  
# fitting the model for grid search
grid.fit(train_pca_w_smote, y_SMOTE)

print(grid.best_params_)

#Create SVM model with best hyperparameters, PCA and SMOTE

svm = make_pipeline(SVC(kernel=grid.best_params_['kernel'], C = grid.best_params_['C'] , gamma=grid.best_params_['gamma']))
svm.fit(train_pca_w_smote, y_SMOTE)
scores = cross_val_score(estimator = svm, X=train_pca_w_smote, y=y_SMOTE, cv=5, n_jobs=1, scoring='f1_weighted')

#print and save output
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 5.1.4\n'
model_type = 'SVM with Hyperparameter tuning, PCA, SMOTE (wav data only)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# Out:
# Before oversampling:  Counter({1: 125, 4: 46, 19: 18, 16: 10, 14: 7, 7: 7, 12: 6, 8: 6, 2: 6})
# (231, 167) (231, 1)
# After oversampling:  Counter({19: 125, 1: 125, 12: 125, 14: 125, 16: 125, 4: 125, 7: 125, 8: 125, 2: 125})
#     Number of PCA Components  Explained Fraction of Total Variance
# 0                          1                              0.804596
# 1                          2                              0.926031
# 2                          3                              0.965587
# 3                          4                              0.978557
# 4                          5                              0.984506
# 5                          6                              0.988856
# 6                          7                              0.991462
# 7                          8                              0.992694
# 8                          9                              0.993724
# 9                         10                              0.994606
# 10                        11                              0.995343
# 11                        12                              0.995948
# 12                        13                              0.996496
# 13                        14                              0.996955
# 14                        15                              0.997335
# 15                        16                              0.997624
# 16                        17                              0.997889
# 17                        18                              0.998130
# 18                        19                              0.998347
# 19                        20                              0.998543
# 20                        21                              0.998729
# 21                        22                              0.998885
# 22                        23                              0.999033
# 23                        24                              0.999137
# {'C': 0.012742749857031334, 'gamma': 0.001, 'kernel': 'linear'}
# Model #: 5.1.4
#  SVM with Hyperparameter tuning, PCA, SMOTE (wav data only)
#  CV Scores [1.         0.98210771 0.98645565 1.         0.99555378]
#  CV Average and standard deviation: 0.9928234273100311 +/- 0.007291589389790084

# %% [markdown]
# #### 5.1.5 Hyperparameter tuning, PCA, SMOTE, Min Max Scaler

# %%
#### MinMaxScaler Application

#Create SVM model with best hyperparameters, PCA and SMOTE and MinMaxScaler

svm = make_pipeline(MinMaxScaler() ,SVC(kernel=grid.best_params_['kernel'], C = grid.best_params_['C'] , gamma=grid.best_params_['gamma']))
svm.fit(train_pca_w_smote, y_SMOTE)
scores = cross_val_score(estimator = svm, X=train_pca_w_smote, y=y_SMOTE, cv=5, n_jobs=1, scoring='f1_weighted')

#Apply 5 fold cross validation scoring to make sure results are reliable
# Print and save output
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 5.1.5\n'
model_type = 'SVM with Hyperparameter tuning, PCA, SMOTE, and Min Max Scaler (wav data only)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# Out:
# Model #: 5.1.5
#  SVM with Hyperparameter tuning, PCA, SMOTE, and Min Max Scaler (wav data only)
#  CV Scores [0.64458848 0.65301601 0.67132446 0.71670103 0.64908452]
#  CV Average and standard deviation: 0.6669428985886697 +/- 0.02648648680937952

# %% [markdown]
# #### 5.1.6 Hyperparameter tuning, PCA, SMOTE, Standard Scaler

# %%
#### Standard Scaler Application

#Create SVM model with best hyperparameters, PCA and SMOTE and StandardScaler

svm = make_pipeline(StandardScaler() ,SVC(kernel=grid.best_params_['kernel'], C = grid.best_params_['C'] , gamma=grid.best_params_['gamma']))
svm.fit(train_pca_w_smote, y_SMOTE)
scores = cross_val_score(estimator = svm, X=train_pca_w_smote, y=y_SMOTE, cv=5, n_jobs=1, scoring='f1_weighted')

#Apply 5 fold cross validation scoring to make sure results are reliable
# Print and save output
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 5.1.6\n'
model_type = 'SVM with Hyperparameter tuning, PCA, SMOTE, and Standard Scaler (wav data only)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# Out:
# Model #: 5.1.6
#  SVM with Hyperparameter tuning, PCA, SMOTE, and Standard Scaler (wav data only)
#  CV Scores [0.93911817 0.91930154 0.95590626 0.94256248 0.95527204]
#  CV Average and standard deviation: 0.9424320964477468 +/- 0.013359933302052329

# %% [markdown]
# ### 5.2 MIDI Data Only

# %% [markdown]
# #### 5.2.1 Baseline model

# %%
#Create baseline SVM model with MIDI Data only

svm = make_pipeline(SVC())
svm.fit(X_train_m, y_train_m.values.ravel())

#Apply 5 fold cross validation scoring to make sure results are reliable

scores = cross_val_score(estimator = svm, X=X_train_m, y=y_train_m.values.ravel(), cv=5,n_jobs=1, scoring='f1_weighted')
# Print and save output
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 5.2.1\n'
model_type = 'SVM Baseline Model (midi data only)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# Out:
# Model #: 5.2.1
#  SVM Baseline Model (midi data only)
#  CV Scores [0.61506698 0.64457282 0.63867212 0.64816685 0.65613692]
#  CV Average and standard deviation: 0.6405231357536184 +/- 0.013928807581877036

# %% [markdown]
# ### 5.3 Combined Data (WAV & MIDI)

# %% [markdown]
# #### 5.3.1 Baseline model

# %%
#Create baseline SVM model with Spectral Wav and MIDI Data

svm = make_pipeline(SVC())
svm.fit(X_train_c, y_train_c.values.ravel())

#Apply 5 fold cross validation scoring to make sure results are reliable

scores = cross_val_score(estimator = svm, X=X_train_c, y=y_train_c.values.ravel(), cv=5,n_jobs=1, scoring='f1_weighted')
output_file = open('../output/dev_results', 'a')
model_no = 'Model #: 5.3.1\n'
model_type = 'SVM with Baseline Model (midi and wav data)\n'
model_scores = f'CV Scores {scores}\n'
model_avg_std = f'CV Average and standard deviation: {np.mean(scores)} +/- {np.std(scores)}\n'
output_file.writelines([model_no, model_type, model_scores, model_avg_std])
output_file.close()
print(model_no, model_type, model_scores, model_avg_std)
# Out:
# Model #: 5.3.1
#  SVM with Baseline Model (midi and wav data)
#  CV Scores [0.61506698 0.64457282 0.63867212 0.64816685 0.65613692]
#  CV Average and standard deviation: 0.6405231357536184 +/- 0.013928807581877036

# %% [markdown]
# ## 6. Neural Network

# %% [markdown]
# ### 6.1 Spectral (WAV) Data Only

# %% [markdown]
# #### 6.1.1 Baseline model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(176, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(90, activation='relu'),
    tf.keras.layers.Dense(80, activation='relu'),
    tf.keras.layers.Dense(70, activation='relu'),
    tf.keras.layers.Dense(60, activation='relu'),
    tf.keras.layers.Dense(21)
])
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
history = model.fit(X_train_w, y_train_w, epochs=200)
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.tight_layout()
plt.savefig('../output/plots/6.1.1 Accuracy Plot.png')

# predict probabilities for train set
yhat_probs = model.predict(X_train_w, verbose=0)
# predict crisp classes for test set
yhat_classes = model.predict_classes(X_train_w, verbose=0)

f1 = f1_score(y_train_w, yhat_classes, average='weighted')
output_file = open('../output/dev_results', 'a')
model_no = 'Model#: 6.1.1\n'
model_type = 'Neural Network (wav data only)\n'
model_scores = "Test Set F1-score: {:.2%}".format(f1)
output_file.writelines([model_no, model_type, model_scores])
output_file.close()
print(model_no, model_type, model_scores)
pass
# Out:
# Epoch 1/200
# 8/8 [==============================] - 1s 1ms/step - loss: 3.7258 - accuracy: 0.2857
# Epoch 2/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8949 - accuracy: 0.4719
# Epoch 3/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4412 - accuracy: 0.5801
# Epoch 4/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1924 - accuracy: 0.6320
# Epoch 5/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9651 - accuracy: 0.7273
# Epoch 6/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.8711 - accuracy: 0.7576
# Epoch 7/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8035 - accuracy: 0.7576
# Epoch 8/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6628 - accuracy: 0.7965
# Epoch 9/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5695 - accuracy: 0.8268
# Epoch 10/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6583 - accuracy: 0.7965
# Epoch 11/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5544 - accuracy: 0.8312
# Epoch 12/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5299 - accuracy: 0.8355
# Epoch 13/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6112 - accuracy: 0.7922
# Epoch 14/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5570 - accuracy: 0.8095
# Epoch 15/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4847 - accuracy: 0.8442
# Epoch 16/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4152 - accuracy: 0.8442
# Epoch 17/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3957 - accuracy: 0.8701
# Epoch 18/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3851 - accuracy: 0.8485
# Epoch 19/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3209 - accuracy: 0.8874
# Epoch 20/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3016 - accuracy: 0.9004
# Epoch 21/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3024 - accuracy: 0.8831
# Epoch 22/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2422 - accuracy: 0.9351
# Epoch 23/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2606 - accuracy: 0.9091
# Epoch 24/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2281 - accuracy: 0.9221
# Epoch 25/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1858 - accuracy: 0.9394
# Epoch 26/200
# 8/8 [==============================] - ETA: 0s - loss: 0.2514 - accuracy: 0.87 - 0s 2ms/step - loss: 0.1614 - accuracy: 0.9481
# Epoch 27/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1461 - accuracy: 0.9610
# Epoch 28/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1838 - accuracy: 0.9437
# Epoch 29/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2088 - accuracy: 0.9307
# Epoch 30/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2750 - accuracy: 0.9134
# Epoch 31/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2760 - accuracy: 0.9048
# Epoch 32/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1721 - accuracy: 0.9481
# Epoch 33/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1426 - accuracy: 0.9567
# Epoch 34/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1560 - accuracy: 0.9481
# Epoch 35/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2079 - accuracy: 0.9307
# Epoch 36/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2232 - accuracy: 0.9394
# Epoch 37/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2541 - accuracy: 0.9264
# Epoch 38/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2590 - accuracy: 0.9221
# Epoch 39/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2170 - accuracy: 0.9177
# Epoch 40/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2479 - accuracy: 0.9091
# Epoch 41/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3042 - accuracy: 0.8918
# Epoch 42/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2875 - accuracy: 0.9004
# Epoch 43/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1839 - accuracy: 0.9481
# Epoch 44/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2663 - accuracy: 0.9091
# Epoch 45/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1914 - accuracy: 0.9307
# Epoch 46/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3257 - accuracy: 0.8788
# Epoch 47/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3685 - accuracy: 0.8918
# Epoch 48/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1724 - accuracy: 0.9394
# Epoch 49/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1507 - accuracy: 0.9481
# Epoch 50/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1169 - accuracy: 0.9524
# Epoch 51/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0995 - accuracy: 0.9740
# Epoch 52/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0936 - accuracy: 0.9697
# Epoch 53/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0773 - accuracy: 0.9827
# Epoch 54/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0691 - accuracy: 0.9827
# Epoch 55/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0584 - accuracy: 0.9827
# Epoch 56/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0577 - accuracy: 0.9784
# Epoch 57/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0755 - accuracy: 0.96 - 0s 5ms/step - loss: 0.0499 - accuracy: 0.9827
# Epoch 58/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0477 - accuracy: 0.9827
# Epoch 59/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0736 - accuracy: 0.9697
# Epoch 60/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0725 - accuracy: 0.9740
# Epoch 61/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0650 - accuracy: 0.9784
# Epoch 62/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0795 - accuracy: 0.9827
# Epoch 63/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0768 - accuracy: 0.9610
# Epoch 64/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0494 - accuracy: 0.9870
# Epoch 65/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0473 - accuracy: 0.9827
# Epoch 66/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0513 - accuracy: 0.9784
# Epoch 67/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0343 - accuracy: 0.9957
# Epoch 68/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0318 - accuracy: 0.9957
# Epoch 69/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0504 - accuracy: 0.9827
# Epoch 70/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0705 - accuracy: 0.9827
# Epoch 71/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0806 - accuracy: 0.9740
# Epoch 72/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0978 - accuracy: 0.9697
# Epoch 73/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1718 - accuracy: 0.9481
# Epoch 74/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2045 - accuracy: 0.9264
# Epoch 75/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1278 - accuracy: 0.9567
# Epoch 76/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0973 - accuracy: 0.9610
# Epoch 77/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0753 - accuracy: 0.9610
# Epoch 78/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0684 - accuracy: 0.9697
# Epoch 79/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0616 - accuracy: 0.9784
# Epoch 80/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0479 - accuracy: 0.9870
# Epoch 81/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0387 - accuracy: 0.9870
# Epoch 82/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0268 - accuracy: 0.9870
# Epoch 83/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 0.9957
# Epoch 84/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 85/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 86/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0124 - accuracy: 0.9957
# Epoch 87/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 88/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 89/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 90/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 91/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 92/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 93/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 94/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 95/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 96/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 97/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 98/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 99/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 100/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 101/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 102/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 103/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 104/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 105/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 106/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 107/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 108/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 109/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 110/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 111/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 112/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 113/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 114/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 115/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 116/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 117/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 118/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 119/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 120/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 121/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 122/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 123/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 124/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 125/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 126/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 127/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 128/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 129/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 130/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 131/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 132/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 133/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 134/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 135/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 136/200
# 8/8 [==============================] - 0s 2ms/step - loss: 9.3271e-04 - accuracy: 1.0000
# Epoch 137/200
# 8/8 [==============================] - 0s 2ms/step - loss: 9.1290e-04 - accuracy: 1.0000
# Epoch 138/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.7941e-04 - accuracy: 1.0000
# Epoch 139/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.2459e-04 - accuracy: 1.0000
# Epoch 140/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.9169e-04 - accuracy: 1.0000
# Epoch 141/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.7800e-04 - accuracy: 1.0000
# Epoch 142/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.6343e-04 - accuracy: 1.0000
# Epoch 143/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.4468e-04 - accuracy: 1.0000
# Epoch 144/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.4345e-04 - accuracy: 1.0000
# Epoch 145/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.1252e-04 - accuracy: 1.0000
# Epoch 146/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.0109e-04 - accuracy: 1.0000
# Epoch 147/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.6771e-04 - accuracy: 1.0000
# Epoch 148/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.5315e-04 - accuracy: 1.0000
# Epoch 149/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.2270e-04 - accuracy: 1.0000
# Epoch 150/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.1461e-04 - accuracy: 1.0000
# Epoch 151/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.9030e-04 - accuracy: 1.0000
# Epoch 152/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.7490e-04 - accuracy: 1.0000
# Epoch 153/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.6526e-04 - accuracy: 1.0000
# Epoch 154/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.6916e-04 - accuracy: 1.0000
# Epoch 155/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.8591e-04 - accuracy: 1.0000
# Epoch 156/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.7607e-04 - accuracy: 1.0000
# Epoch 157/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.6812e-04 - accuracy: 1.0000
# Epoch 158/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.2264e-04 - accuracy: 1.0000
# Epoch 159/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.2844e-04 - accuracy: 1.0000
# Epoch 160/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.8359e-04 - accuracy: 1.0000
# Epoch 161/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.7756e-04 - accuracy: 1.0000
# Epoch 162/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.7366e-04 - accuracy: 1.0000
# Epoch 163/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.6322e-04 - accuracy: 1.0000
# Epoch 164/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.4130e-04 - accuracy: 1.0000
# Epoch 165/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.4161e-04 - accuracy: 1.0000
# Epoch 166/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.3169e-04 - accuracy: 1.0000
# Epoch 167/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.1922e-04 - accuracy: 1.0000
# Epoch 168/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0831e-04 - accuracy: 1.0000
# Epoch 169/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9674e-04 - accuracy: 1.0000
# Epoch 170/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.2320e-04 - accuracy: 1.0000
# Epoch 171/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9254e-04 - accuracy: 1.0000
# Epoch 172/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9435e-04 - accuracy: 1.0000
# Epoch 173/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9512e-04 - accuracy: 1.0000
# Epoch 174/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.8029e-04 - accuracy: 1.0000
# Epoch 175/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.6387e-04 - accuracy: 1.0000
# Epoch 176/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5917e-04 - accuracy: 1.0000
# Epoch 177/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4889e-04 - accuracy: 1.0000
# Epoch 178/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5117e-04 - accuracy: 1.0000
# Epoch 179/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4470e-04 - accuracy: 1.0000
# Epoch 180/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.2969e-04 - accuracy: 1.0000
# Epoch 181/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.2265e-04 - accuracy: 1.0000
# Epoch 182/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.1857e-04 - accuracy: 1.0000
# Epoch 183/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.1451e-04 - accuracy: 1.0000
# Epoch 184/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.0999e-04 - accuracy: 1.0000
# Epoch 185/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.0575e-04 - accuracy: 1.0000
# Epoch 186/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.0067e-04 - accuracy: 1.0000
# Epoch 187/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.9180e-04 - accuracy: 1.0000
# Epoch 188/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.8982e-04 - accuracy: 1.0000
# Epoch 189/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.8171e-04 - accuracy: 1.0000
# Epoch 190/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.9790e-04 - accuracy: 1.0000
# Epoch 191/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.0992e-04 - accuracy: 1.0000
# Epoch 192/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.8426e-04 - accuracy: 1.0000
# Epoch 193/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.7227e-04 - accuracy: 1.0000
# Epoch 194/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.6649e-04 - accuracy: 1.0000
# Epoch 195/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.5981e-04 - accuracy: 1.0000
# Epoch 196/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.5987e-04 - accuracy: 1.0000
# Epoch 197/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.4509e-04 - accuracy: 1.0000
# Epoch 198/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.4395e-04 - accuracy: 1.0000
# Epoch 199/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.4852e-04 - accuracy: 1.0000
# Epoch 200/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.3723e-04 - accuracy: 1.0000
# Model#: 6.1.1
#  Neural Network (wav data only)
#  Test Set F1-score: 100.00%

# %% [markdown]
# #### observation: only using the wave features has the strongest performance in a neral network

# %% [markdown]
# ### 6.2 MIDI Data Only

# %% [markdown]
# #### 6.2.1 Baseline model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(176, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(90, activation='relu'),
    tf.keras.layers.Dense(80, activation='relu'),
    tf.keras.layers.Dense(70, activation='relu'),
    tf.keras.layers.Dense(60, activation='relu'),
    tf.keras.layers.Dense(21)
])
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
history = model.fit(X_train_m, y_train_m, epochs=200)
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.tight_layout()
plt.savefig('../output/plots/6.2.1 Accuracy Plot.png')


# predict probabilities for train set
yhat_probs = model.predict(X_train_m, verbose=0)
# predict crisp classes for test set
yhat_classes = model.predict_classes(X_train_m, verbose=0)

f1 = f1_score(y_train_m, yhat_classes, average='weighted')

output_file = open('../output/dev_results', 'a')
model_no = 'Model#: 6.2.1\n'
model_type = 'Neural Network (midi data only)\n'
model_scores = "Test Set F1-score: {:.2%}".format(f1)
output_file.writelines([model_no, model_type, model_scores])
output_file.close()
print(model_no, model_type, model_scores)
pass
# Out:
# Epoch 1/200
# 8/8 [==============================] - 1s 2ms/step - loss: 3148.5493 - accuracy: 0.4069
# Epoch 2/200
# 8/8 [==============================] - 0s 2ms/step - loss: 556.6666 - accuracy: 0.5931
# Epoch 3/200
# 8/8 [==============================] - 0s 2ms/step - loss: 408.4542 - accuracy: 0.5541
# Epoch 4/200
# 8/8 [==============================] - 0s 2ms/step - loss: 197.8449 - accuracy: 0.6926
# Epoch 5/200
# 8/8 [==============================] - 0s 2ms/step - loss: 96.4847 - accuracy: 0.7100
# Epoch 6/200
# 8/8 [==============================] - 0s 2ms/step - loss: 79.5475 - accuracy: 0.6926
# Epoch 7/200
# 8/8 [==============================] - 0s 2ms/step - loss: 82.0815 - accuracy: 0.8139
# Epoch 8/200
# 8/8 [==============================] - 0s 2ms/step - loss: 95.1105 - accuracy: 0.7273
# Epoch 9/200
# 8/8 [==============================] - 0s 2ms/step - loss: 137.0992 - accuracy: 0.7143
# Epoch 10/200
# 8/8 [==============================] - 0s 2ms/step - loss: 209.0257 - accuracy: 0.6840
# Epoch 11/200
# 8/8 [==============================] - 0s 2ms/step - loss: 180.5658 - accuracy: 0.6883
# Epoch 12/200
# 8/8 [==============================] - 0s 3ms/step - loss: 147.4364 - accuracy: 0.7056
# Epoch 13/200
# 8/8 [==============================] - 0s 3ms/step - loss: 104.5806 - accuracy: 0.8095
# Epoch 14/200
# 8/8 [==============================] - 0s 3ms/step - loss: 78.7675 - accuracy: 0.6926
# Epoch 15/200
# 8/8 [==============================] - 0s 4ms/step - loss: 114.6281 - accuracy: 0.7835
# Epoch 16/200
# 8/8 [==============================] - 0s 9ms/step - loss: 143.7958 - accuracy: 0.6883
# Epoch 17/200
# 8/8 [==============================] - 0s 6ms/step - loss: 148.2467 - accuracy: 0.6710
# Epoch 18/200
# 8/8 [==============================] - 0s 3ms/step - loss: 112.1651 - accuracy: 0.7532
# Epoch 19/200
# 8/8 [==============================] - 0s 4ms/step - loss: 133.6827 - accuracy: 0.7965
# Epoch 20/200
# 8/8 [==============================] - 0s 3ms/step - loss: 100.3232 - accuracy: 0.7143
# Epoch 21/200
# 8/8 [==============================] - 0s 5ms/step - loss: 97.9511 - accuracy: 0.7706
# Epoch 22/200
# 8/8 [==============================] - ETA: 0s - loss: 167.5576 - accuracy: 0.84 - 0s 4ms/step - loss: 121.3213 - accuracy: 0.7749
# Epoch 23/200
# 8/8 [==============================] - 0s 3ms/step - loss: 131.8855 - accuracy: 0.6797
# Epoch 24/200
# 8/8 [==============================] - 0s 3ms/step - loss: 105.9178 - accuracy: 0.8139
# Epoch 25/200
# 8/8 [==============================] - 0s 3ms/step - loss: 105.8339 - accuracy: 0.8225
# Epoch 26/200
# 8/8 [==============================] - 0s 3ms/step - loss: 103.2606 - accuracy: 0.7576
# Epoch 27/200
# 8/8 [==============================] - 0s 2ms/step - loss: 117.6955 - accuracy: 0.6190
# Epoch 28/200
# 8/8 [==============================] - 0s 3ms/step - loss: 152.8884 - accuracy: 0.7100
# Epoch 29/200
# 8/8 [==============================] - 0s 2ms/step - loss: 87.9907 - accuracy: 0.8312
# Epoch 30/200
# 8/8 [==============================] - 0s 2ms/step - loss: 52.5592 - accuracy: 0.7749
# Epoch 31/200
# 8/8 [==============================] - 0s 3ms/step - loss: 41.0381 - accuracy: 0.7835
# Epoch 32/200
# 8/8 [==============================] - 0s 2ms/step - loss: 56.2484 - accuracy: 0.7316
# Epoch 33/200
# 8/8 [==============================] - 0s 2ms/step - loss: 76.6533 - accuracy: 0.7532
# Epoch 34/200
# 8/8 [==============================] - 0s 2ms/step - loss: 94.2823 - accuracy: 0.8398
# Epoch 35/200
# 8/8 [==============================] - 0s 2ms/step - loss: 98.3365 - accuracy: 0.7532
# Epoch 36/200
# 8/8 [==============================] - 0s 3ms/step - loss: 78.0602 - accuracy: 0.8442
# Epoch 37/200
# 8/8 [==============================] - 0s 3ms/step - loss: 48.2516 - accuracy: 0.7922
# Epoch 38/200
# 8/8 [==============================] - 0s 2ms/step - loss: 40.9777 - accuracy: 0.7229
# Epoch 39/200
# 8/8 [==============================] - 0s 2ms/step - loss: 50.2946 - accuracy: 0.8355
# Epoch 40/200
# 8/8 [==============================] - 0s 3ms/step - loss: 49.1021 - accuracy: 0.7835
# Epoch 41/200
# 8/8 [==============================] - 0s 2ms/step - loss: 45.0646 - accuracy: 0.7749
# Epoch 42/200
# 8/8 [==============================] - 0s 2ms/step - loss: 43.6974 - accuracy: 0.6667
# Epoch 43/200
# 8/8 [==============================] - 0s 2ms/step - loss: 62.1799 - accuracy: 0.8052
# Epoch 44/200
# 8/8 [==============================] - 0s 2ms/step - loss: 45.5083 - accuracy: 0.7446
# Epoch 45/200
# 8/8 [==============================] - 0s 2ms/step - loss: 38.3507 - accuracy: 0.8355
# Epoch 46/200
# 8/8 [==============================] - 0s 2ms/step - loss: 14.7991 - accuracy: 0.7965
# Epoch 47/200
# 8/8 [==============================] - 0s 2ms/step - loss: 12.0589 - accuracy: 0.7576
# Epoch 48/200
# 8/8 [==============================] - 0s 2ms/step - loss: 23.8661 - accuracy: 0.7792
# Epoch 49/200
# 8/8 [==============================] - 0s 3ms/step - loss: 42.3181 - accuracy: 0.8312
# Epoch 50/200
# 8/8 [==============================] - 0s 3ms/step - loss: 33.1558 - accuracy: 0.8182
# Epoch 51/200
# 8/8 [==============================] - 0s 4ms/step - loss: 23.9995 - accuracy: 0.8095
# Epoch 52/200
# 8/8 [==============================] - 0s 6ms/step - loss: 25.7809 - accuracy: 0.8442
# Epoch 53/200
# 8/8 [==============================] - 0s 3ms/step - loss: 15.2715 - accuracy: 0.7273
# Epoch 54/200
# 8/8 [==============================] - 0s 3ms/step - loss: 12.9610 - accuracy: 0.8095
# Epoch 55/200
# 8/8 [==============================] - 0s 3ms/step - loss: 12.0281 - accuracy: 0.7662
# Epoch 56/200
# 8/8 [==============================] - 0s 5ms/step - loss: 16.2616 - accuracy: 0.8312
# Epoch 57/200
# 8/8 [==============================] - 0s 4ms/step - loss: 23.6746 - accuracy: 0.8615
# Epoch 58/200
# 8/8 [==============================] - 0s 4ms/step - loss: 15.1265 - accuracy: 0.7922
# Epoch 59/200
# 8/8 [==============================] - 0s 4ms/step - loss: 10.6044 - accuracy: 0.7922
# Epoch 60/200
# 8/8 [==============================] - ETA: 0s - loss: 12.6443 - accuracy: 0.718 - 0s 3ms/step - loss: 13.8737 - accuracy: 0.7922
# Epoch 61/200
# 8/8 [==============================] - 0s 3ms/step - loss: 37.4541 - accuracy: 0.7273
# Epoch 62/200
# 8/8 [==============================] - 0s 2ms/step - loss: 34.8432 - accuracy: 0.7662
# Epoch 63/200
# 8/8 [==============================] - 0s 3ms/step - loss: 23.8751 - accuracy: 0.8312
# Epoch 64/200
# 8/8 [==============================] - 0s 2ms/step - loss: 28.8730 - accuracy: 0.6970
# Epoch 65/200
# 8/8 [==============================] - 0s 3ms/step - loss: 22.3898 - accuracy: 0.8485
# Epoch 66/200
# 8/8 [==============================] - 0s 3ms/step - loss: 24.4780 - accuracy: 0.7359
# Epoch 67/200
# 8/8 [==============================] - 0s 3ms/step - loss: 72.0658 - accuracy: 0.7749
# Epoch 68/200
# 8/8 [==============================] - 0s 2ms/step - loss: 38.7344 - accuracy: 0.7792
# Epoch 69/200
# 8/8 [==============================] - 0s 3ms/step - loss: 36.7395 - accuracy: 0.8009
# Epoch 70/200
# 8/8 [==============================] - 0s 3ms/step - loss: 47.4186 - accuracy: 0.6450
# Epoch 71/200
# 8/8 [==============================] - 0s 4ms/step - loss: 37.0215 - accuracy: 0.7965
# Epoch 72/200
# 8/8 [==============================] - 0s 3ms/step - loss: 39.3241 - accuracy: 0.8095
# Epoch 73/200
# 8/8 [==============================] - 0s 3ms/step - loss: 24.5204 - accuracy: 0.7792
# Epoch 74/200
# 8/8 [==============================] - 0s 2ms/step - loss: 20.0079 - accuracy: 0.8268
# Epoch 75/200
# 8/8 [==============================] - 0s 3ms/step - loss: 13.0631 - accuracy: 0.7662
# Epoch 76/200
# 8/8 [==============================] - 0s 2ms/step - loss: 13.0655 - accuracy: 0.7879
# Epoch 77/200
# 8/8 [==============================] - 0s 2ms/step - loss: 20.3906 - accuracy: 0.7143
# Epoch 78/200
# 8/8 [==============================] - 0s 2ms/step - loss: 27.3562 - accuracy: 0.8052
# Epoch 79/200
# 8/8 [==============================] - 0s 2ms/step - loss: 27.5863 - accuracy: 0.8312
# Epoch 80/200
# 8/8 [==============================] - 0s 2ms/step - loss: 25.0170 - accuracy: 0.8312
# Epoch 81/200
# 8/8 [==============================] - 0s 2ms/step - loss: 11.9786 - accuracy: 0.7749
# Epoch 82/200
# 8/8 [==============================] - 0s 2ms/step - loss: 16.3469 - accuracy: 0.7706
# Epoch 83/200
# 8/8 [==============================] - 0s 2ms/step - loss: 15.6671 - accuracy: 0.7922
# Epoch 84/200
# 8/8 [==============================] - 0s 2ms/step - loss: 42.7938 - accuracy: 0.7316
# Epoch 85/200
# 8/8 [==============================] - 0s 2ms/step - loss: 63.4917 - accuracy: 0.7316
# Epoch 86/200
# 8/8 [==============================] - 0s 2ms/step - loss: 61.0463 - accuracy: 0.6970
# Epoch 87/200
# 8/8 [==============================] - 0s 2ms/step - loss: 53.9924 - accuracy: 0.8009
# Epoch 88/200
# 8/8 [==============================] - 0s 2ms/step - loss: 55.9730 - accuracy: 0.7619
# Epoch 89/200
# 8/8 [==============================] - 0s 2ms/step - loss: 41.8176 - accuracy: 0.7229
# Epoch 90/200
# 8/8 [==============================] - 0s 2ms/step - loss: 48.9798 - accuracy: 0.7100
# Epoch 91/200
# 8/8 [==============================] - 0s 2ms/step - loss: 61.8780 - accuracy: 0.8225
# Epoch 92/200
# 8/8 [==============================] - 0s 2ms/step - loss: 41.0568 - accuracy: 0.6710
# Epoch 93/200
# 8/8 [==============================] - 0s 2ms/step - loss: 40.6885 - accuracy: 0.8442
# Epoch 94/200
# 8/8 [==============================] - 0s 2ms/step - loss: 31.3679 - accuracy: 0.7359
# Epoch 95/200
# 8/8 [==============================] - 0s 2ms/step - loss: 30.2705 - accuracy: 0.7489
# Epoch 96/200
# 8/8 [==============================] - 0s 2ms/step - loss: 24.1815 - accuracy: 0.8052
# Epoch 97/200
# 8/8 [==============================] - 0s 2ms/step - loss: 16.3687 - accuracy: 0.7229
# Epoch 98/200
# 8/8 [==============================] - 0s 2ms/step - loss: 26.6548 - accuracy: 0.8009
# Epoch 99/200
# 8/8 [==============================] - 0s 2ms/step - loss: 16.4242 - accuracy: 0.7749
# Epoch 100/200
# 8/8 [==============================] - 0s 2ms/step - loss: 31.2733 - accuracy: 0.8052
# Epoch 101/200
# 8/8 [==============================] - 0s 2ms/step - loss: 24.1558 - accuracy: 0.7143
# Epoch 102/200
# 8/8 [==============================] - 0s 2ms/step - loss: 29.7572 - accuracy: 0.8095
# Epoch 103/200
# 8/8 [==============================] - 0s 2ms/step - loss: 29.1906 - accuracy: 0.8139
# Epoch 104/200
# 8/8 [==============================] - 0s 2ms/step - loss: 39.3069 - accuracy: 0.7403
# Epoch 105/200
# 8/8 [==============================] - 0s 2ms/step - loss: 19.9542 - accuracy: 0.8139
# Epoch 106/200
# 8/8 [==============================] - 0s 2ms/step - loss: 18.7734 - accuracy: 0.7143
# Epoch 107/200
# 8/8 [==============================] - 0s 2ms/step - loss: 21.2243 - accuracy: 0.8355
# Epoch 108/200
# 8/8 [==============================] - 0s 2ms/step - loss: 16.6021 - accuracy: 0.8182
# Epoch 109/200
# 8/8 [==============================] - 0s 2ms/step - loss: 18.3434 - accuracy: 0.8312
# Epoch 110/200
# 8/8 [==============================] - 0s 2ms/step - loss: 14.4787 - accuracy: 0.6970
# Epoch 111/200
# 8/8 [==============================] - 0s 2ms/step - loss: 23.4431 - accuracy: 0.8442
# Epoch 112/200
# 8/8 [==============================] - 0s 2ms/step - loss: 16.5697 - accuracy: 0.7792
# Epoch 113/200
# 8/8 [==============================] - 0s 2ms/step - loss: 11.8956 - accuracy: 0.8268
# Epoch 114/200
# 8/8 [==============================] - 0s 3ms/step - loss: 7.7205 - accuracy: 0.7922
# Epoch 115/200
# 8/8 [==============================] - 0s 2ms/step - loss: 13.6347 - accuracy: 0.7835
# Epoch 116/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.8596 - accuracy: 0.7835
# Epoch 117/200
# 8/8 [==============================] - 0s 3ms/step - loss: 9.5557 - accuracy: 0.7273
# Epoch 118/200
# 8/8 [==============================] - 0s 2ms/step - loss: 14.7838 - accuracy: 0.8528
# Epoch 119/200
# 8/8 [==============================] - 0s 3ms/step - loss: 11.0549 - accuracy: 0.8182
# Epoch 120/200
# 8/8 [==============================] - 0s 3ms/step - loss: 7.3400 - accuracy: 0.8355
# Epoch 121/200
# 8/8 [==============================] - 0s 3ms/step - loss: 11.2282 - accuracy: 0.7576
# Epoch 122/200
# 8/8 [==============================] - 0s 3ms/step - loss: 11.8887 - accuracy: 0.8095
# Epoch 123/200
# 8/8 [==============================] - 0s 3ms/step - loss: 11.4127 - accuracy: 0.7879
# Epoch 124/200
# 8/8 [==============================] - 0s 2ms/step - loss: 10.9120 - accuracy: 0.8225
# Epoch 125/200
# 8/8 [==============================] - 0s 2ms/step - loss: 14.2237 - accuracy: 0.8312
# Epoch 126/200
# 8/8 [==============================] - 0s 3ms/step - loss: 19.2393 - accuracy: 0.8052
# Epoch 127/200
# 8/8 [==============================] - 0s 4ms/step - loss: 14.1146 - accuracy: 0.7662
# Epoch 128/200
# 8/8 [==============================] - 0s 5ms/step - loss: 15.1200 - accuracy: 0.8355
# Epoch 129/200
# 8/8 [==============================] - 0s 4ms/step - loss: 8.3568 - accuracy: 0.7359
# Epoch 130/200
# 8/8 [==============================] - 0s 5ms/step - loss: 4.1794 - accuracy: 0.7706
# Epoch 131/200
# 8/8 [==============================] - 0s 3ms/step - loss: 11.3127 - accuracy: 0.8009
# Epoch 132/200
# 8/8 [==============================] - 0s 3ms/step - loss: 6.6296 - accuracy: 0.7706
# Epoch 133/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.6599 - accuracy: 0.7706
# Epoch 134/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.7422 - accuracy: 0.7100
# Epoch 135/200
# 8/8 [==============================] - 0s 2ms/step - loss: 10.9561 - accuracy: 0.8615
# Epoch 136/200
# 8/8 [==============================] - 0s 3ms/step - loss: 8.1725 - accuracy: 0.7965
# Epoch 137/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.1526 - accuracy: 0.7965
# Epoch 138/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.0996 - accuracy: 0.8268
# Epoch 139/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.8534 - accuracy: 0.7576
# Epoch 140/200
# 8/8 [==============================] - 0s 2ms/step - loss: 10.4057 - accuracy: 0.8139
# Epoch 141/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.2055 - accuracy: 0.8528
# Epoch 142/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.4727 - accuracy: 0.8052
# Epoch 143/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.0692 - accuracy: 0.7229
# Epoch 144/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.1114 - accuracy: 0.7879
# Epoch 145/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.0057 - accuracy: 0.8355
# Epoch 146/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.2015 - accuracy: 0.7403
# Epoch 147/200
# 8/8 [==============================] - 0s 2ms/step - loss: 12.0538 - accuracy: 0.7706
# Epoch 148/200
# 8/8 [==============================] - 0s 2ms/step - loss: 10.9912 - accuracy: 0.8485
# Epoch 149/200
# 8/8 [==============================] - 0s 2ms/step - loss: 9.7929 - accuracy: 0.7706
# Epoch 150/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.3424 - accuracy: 0.8355
# Epoch 151/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5405 - accuracy: 0.7922
# Epoch 152/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.4042 - accuracy: 0.7273
# Epoch 153/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9074 - accuracy: 0.8268
# Epoch 154/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.7763 - accuracy: 0.7532
# Epoch 155/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.4157 - accuracy: 0.7229
# Epoch 156/200
# 8/8 [==============================] - 0s 2ms/step - loss: 12.3563 - accuracy: 0.8398
# Epoch 157/200
# 8/8 [==============================] - 0s 2ms/step - loss: 10.4875 - accuracy: 0.7229
# Epoch 158/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.8633 - accuracy: 0.8485
# Epoch 159/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.9445 - accuracy: 0.7706
# Epoch 160/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.1897 - accuracy: 0.8268
# Epoch 161/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.3138 - accuracy: 0.8398
# Epoch 162/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.5683 - accuracy: 0.7403
# Epoch 163/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.3391 - accuracy: 0.7706
# Epoch 164/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0199 - accuracy: 0.8268
# Epoch 165/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.6640 - accuracy: 0.7532
# Epoch 166/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5562 - accuracy: 0.8009
# Epoch 167/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0896 - accuracy: 0.7532
# Epoch 168/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9551 - accuracy: 0.8009
# Epoch 169/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.8904 - accuracy: 0.7922
# Epoch 170/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.2558 - accuracy: 0.6883
# Epoch 171/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.5121 - accuracy: 0.8571
# Epoch 172/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.4316 - accuracy: 0.8009
# Epoch 173/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.7523 - accuracy: 0.7879
# Epoch 174/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.0605 - accuracy: 0.7359
# Epoch 175/200
# 8/8 [==============================] - 0s 3ms/step - loss: 5.0890 - accuracy: 0.8658
# Epoch 176/200
# 8/8 [==============================] - 0s 3ms/step - loss: 7.2340 - accuracy: 0.8009
# Epoch 177/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.2070 - accuracy: 0.7965
# Epoch 178/200
# 8/8 [==============================] - 0s 3ms/step - loss: 7.3178 - accuracy: 0.8225
# Epoch 179/200
# 8/8 [==============================] - 0s 3ms/step - loss: 6.7308 - accuracy: 0.7835
# Epoch 180/200
# 8/8 [==============================] - 0s 3ms/step - loss: 7.9343 - accuracy: 0.8312
# Epoch 181/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.9236 - accuracy: 0.8182
# Epoch 182/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.6346 - accuracy: 0.8485
# Epoch 183/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.6863 - accuracy: 0.7879
# Epoch 184/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4364 - accuracy: 0.8095
# Epoch 185/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.4162 - accuracy: 0.7143
# Epoch 186/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.9350 - accuracy: 0.7922
# Epoch 187/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8613 - accuracy: 0.8268
# Epoch 188/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.2530 - accuracy: 0.7879
# Epoch 189/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.8489 - accuracy: 0.7749
# Epoch 190/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.6926 - accuracy: 0.8571
# Epoch 191/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.6310 - accuracy: 0.7879
# Epoch 192/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.0107 - accuracy: 0.7965
# Epoch 193/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4519 - accuracy: 0.8052
# Epoch 194/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9796 - accuracy: 0.8485
# Epoch 195/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.1003 - accuracy: 0.8095
# Epoch 196/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.8684 - accuracy: 0.8615
# Epoch 197/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1318 - accuracy: 0.8009
# Epoch 198/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9868 - accuracy: 0.8398
# Epoch 199/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9975 - accuracy: 0.8095
# Epoch 200/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.9700 - accuracy: 0.8745
# Model#: 6.2.1
#  Neural Network (midi data only)
#  Test Set F1-score: 62.26%

# %% [markdown]
# ### 6.3 Combined Data (WAV & MIDI)

# %% [markdown]
# #### 6.3.1 Baseline model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(176, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(90, activation='relu'),
    tf.keras.layers.Dense(80, activation='relu'),
    tf.keras.layers.Dense(70, activation='relu'),
    tf.keras.layers.Dense(60, activation='relu'),
    tf.keras.layers.Dense(21)
])
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
history = model.fit(X_train_c, y_train_c, epochs=200)
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.tight_layout()
plt.savefig('../output/plots/6.3.1 Accuracy Plot.png')

# predict probabilities for train set
yhat_probs = model.predict(X_train_c, verbose=0)
# predict crisp classes for test set
yhat_classes = model.predict_classes(X_train_c, verbose=0)

f1 = f1_score(y_train_c, yhat_classes, average='weighted')
output_file = open('../output/dev_results', 'a')
model_no = 'Model#: 6.3.1\n'
model_type = 'Neural Network (midi and wav data)\n'
model_scores = "Test Set F1-score: {:.2%}".format(f1)
output_file.writelines([model_no, model_type, model_scores])
output_file.close()
print(model_no, model_type, model_scores)
pass
# Out:
# Epoch 1/200
# 8/8 [==============================] - 1s 3ms/step - loss: 4759.7935 - accuracy: 0.1688
# Epoch 2/200
# 8/8 [==============================] - 0s 3ms/step - loss: 602.7956 - accuracy: 0.4416
# Epoch 3/200
# 8/8 [==============================] - 0s 4ms/step - loss: 273.2398 - accuracy: 0.6017
# Epoch 4/200
# 8/8 [==============================] - 0s 4ms/step - loss: 153.7982 - accuracy: 0.6450
# Epoch 5/200
# 8/8 [==============================] - 0s 4ms/step - loss: 75.8806 - accuracy: 0.7056
# Epoch 6/200
# 8/8 [==============================] - 0s 3ms/step - loss: 75.1456 - accuracy: 0.7706
# Epoch 7/200
# 8/8 [==============================] - 0s 3ms/step - loss: 51.6257 - accuracy: 0.7619
# Epoch 8/200
# 8/8 [==============================] - 0s 3ms/step - loss: 50.0366 - accuracy: 0.7749
# Epoch 9/200
# 8/8 [==============================] - 0s 3ms/step - loss: 70.1131 - accuracy: 0.6623
# Epoch 10/200
# 8/8 [==============================] - 0s 3ms/step - loss: 96.8933 - accuracy: 0.7619
# Epoch 11/200
# 8/8 [==============================] - 0s 4ms/step - loss: 59.4630 - accuracy: 0.7619
# Epoch 12/200
# 8/8 [==============================] - 0s 3ms/step - loss: 72.8445 - accuracy: 0.7706
# Epoch 13/200
# 8/8 [==============================] - 0s 4ms/step - loss: 62.4473 - accuracy: 0.8139
# Epoch 14/200
# 8/8 [==============================] - 0s 3ms/step - loss: 50.2018 - accuracy: 0.7143
# Epoch 15/200
# 8/8 [==============================] - 0s 3ms/step - loss: 30.9961 - accuracy: 0.8225
# Epoch 16/200
# 8/8 [==============================] - 0s 3ms/step - loss: 28.3465 - accuracy: 0.8312
# Epoch 17/200
# 8/8 [==============================] - 0s 3ms/step - loss: 53.7473 - accuracy: 0.7100
# Epoch 18/200
# 8/8 [==============================] - 0s 4ms/step - loss: 51.5582 - accuracy: 0.7532
# Epoch 19/200
# 8/8 [==============================] - 0s 3ms/step - loss: 47.0130 - accuracy: 0.7619
# Epoch 20/200
# 8/8 [==============================] - 0s 3ms/step - loss: 26.4910 - accuracy: 0.7403
# Epoch 21/200
# 8/8 [==============================] - 0s 3ms/step - loss: 36.9398 - accuracy: 0.7619
# Epoch 22/200
# 8/8 [==============================] - 0s 3ms/step - loss: 96.5853 - accuracy: 0.6797
# Epoch 23/200
# 8/8 [==============================] - 0s 3ms/step - loss: 49.6929 - accuracy: 0.8009
# Epoch 24/200
# 8/8 [==============================] - 0s 3ms/step - loss: 36.0888 - accuracy: 0.7056
# Epoch 25/200
# 8/8 [==============================] - 0s 3ms/step - loss: 56.4056 - accuracy: 0.7749
# Epoch 26/200
# 8/8 [==============================] - 0s 3ms/step - loss: 31.4655 - accuracy: 0.7965
# Epoch 27/200
# 8/8 [==============================] - 0s 3ms/step - loss: 41.8831 - accuracy: 0.6450
# Epoch 28/200
# 8/8 [==============================] - 0s 3ms/step - loss: 39.2493 - accuracy: 0.8139
# Epoch 29/200
# 8/8 [==============================] - 0s 4ms/step - loss: 30.9908 - accuracy: 0.7619
# Epoch 30/200
# 8/8 [==============================] - 0s 3ms/step - loss: 21.2576 - accuracy: 0.7662
# Epoch 31/200
# 8/8 [==============================] - 0s 4ms/step - loss: 40.3501 - accuracy: 0.8268
# Epoch 32/200
# 8/8 [==============================] - 0s 6ms/step - loss: 45.0348 - accuracy: 0.8182
# Epoch 33/200
# 8/8 [==============================] - 0s 8ms/step - loss: 42.4856 - accuracy: 0.8268A: 0s - loss: 42.4856 - accuracy: 0.826
# Epoch 34/200
# 8/8 [==============================] - 0s 6ms/step - loss: 27.6702 - accuracy: 0.6926
# Epoch 35/200
# 8/8 [==============================] - 0s 5ms/step - loss: 32.1385 - accuracy: 0.8398
# Epoch 36/200
# 8/8 [==============================] - 0s 8ms/step - loss: 32.1815 - accuracy: 0.8009
# Epoch 37/200
# 8/8 [==============================] - 0s 5ms/step - loss: 24.2525 - accuracy: 0.8009
# Epoch 38/200
# 8/8 [==============================] - 0s 6ms/step - loss: 31.8175 - accuracy: 0.7359
# Epoch 39/200
# 8/8 [==============================] - 0s 4ms/step - loss: 47.7832 - accuracy: 0.7186
# Epoch 40/200
# 8/8 [==============================] - 0s 5ms/step - loss: 33.4899 - accuracy: 0.7792
# Epoch 41/200
# 8/8 [==============================] - 0s 6ms/step - loss: 32.8089 - accuracy: 0.8355
# Epoch 42/200
# 8/8 [==============================] - 0s 4ms/step - loss: 20.0460 - accuracy: 0.8095
# Epoch 43/200
# 8/8 [==============================] - 0s 3ms/step - loss: 17.1287 - accuracy: 0.8182
# Epoch 44/200
# 8/8 [==============================] - 0s 3ms/step - loss: 15.0914 - accuracy: 0.7662
# Epoch 45/200
# 8/8 [==============================] - 0s 2ms/step - loss: 22.3240 - accuracy: 0.8398
# Epoch 46/200
# 8/8 [==============================] - 0s 2ms/step - loss: 14.8669 - accuracy: 0.7489
# Epoch 47/200
# 8/8 [==============================] - 0s 2ms/step - loss: 40.6751 - accuracy: 0.8139
# Epoch 48/200
# 8/8 [==============================] - 0s 2ms/step - loss: 31.5986 - accuracy: 0.8528
# Epoch 49/200
# 8/8 [==============================] - 0s 2ms/step - loss: 35.5808 - accuracy: 0.7792
# Epoch 50/200
# 8/8 [==============================] - 0s 2ms/step - loss: 28.3871 - accuracy: 0.8182
# Epoch 51/200
# 8/8 [==============================] - 0s 2ms/step - loss: 20.1238 - accuracy: 0.8312
# Epoch 52/200
# 8/8 [==============================] - 0s 3ms/step - loss: 14.8434 - accuracy: 0.8312
# Epoch 53/200
# 8/8 [==============================] - 0s 2ms/step - loss: 15.0061 - accuracy: 0.8095
# Epoch 54/200
# 8/8 [==============================] - 0s 2ms/step - loss: 14.2162 - accuracy: 0.8571
# Epoch 55/200
# 8/8 [==============================] - 0s 2ms/step - loss: 10.5337 - accuracy: 0.7489
# Epoch 56/200
# 8/8 [==============================] - 0s 2ms/step - loss: 10.9746 - accuracy: 0.7792
# Epoch 57/200
# 8/8 [==============================] - 0s 2ms/step - loss: 11.0538 - accuracy: 0.8095
# Epoch 58/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.7381 - accuracy: 0.8355
# Epoch 59/200
# 8/8 [==============================] - 0s 2ms/step - loss: 45.1672 - accuracy: 0.6450
# Epoch 60/200
# 8/8 [==============================] - 0s 2ms/step - loss: 18.4064 - accuracy: 0.8225
# Epoch 61/200
# 8/8 [==============================] - 0s 3ms/step - loss: 18.1197 - accuracy: 0.7619
# Epoch 62/200
# 8/8 [==============================] - 0s 3ms/step - loss: 25.3266 - accuracy: 0.7965
# Epoch 63/200
# 8/8 [==============================] - 0s 3ms/step - loss: 18.4280 - accuracy: 0.8139
# Epoch 64/200
# 8/8 [==============================] - 0s 3ms/step - loss: 17.3182 - accuracy: 0.8355
# Epoch 65/200
# 8/8 [==============================] - 0s 5ms/step - loss: 27.8205 - accuracy: 0.8745
# Epoch 66/200
# 8/8 [==============================] - 0s 4ms/step - loss: 21.1817 - accuracy: 0.8398
# Epoch 67/200
# 8/8 [==============================] - 0s 7ms/step - loss: 17.3143 - accuracy: 0.8442
# Epoch 68/200
# 8/8 [==============================] - 0s 6ms/step - loss: 15.2188 - accuracy: 0.7835
# Epoch 69/200
# 8/8 [==============================] - 0s 4ms/step - loss: 17.5487 - accuracy: 0.7922
# Epoch 70/200
# 8/8 [==============================] - 0s 4ms/step - loss: 21.7478 - accuracy: 0.8355
# Epoch 71/200
# 8/8 [==============================] - 0s 3ms/step - loss: 11.6720 - accuracy: 0.7489
# Epoch 72/200
# 8/8 [==============================] - 0s 3ms/step - loss: 7.5543 - accuracy: 0.7489
# Epoch 73/200
# 8/8 [==============================] - 0s 4ms/step - loss: 5.8733 - accuracy: 0.8355
# Epoch 74/200
# 8/8 [==============================] - 0s 3ms/step - loss: 8.0515 - accuracy: 0.7359
# Epoch 75/200
# 8/8 [==============================] - 0s 3ms/step - loss: 10.4105 - accuracy: 0.8182
# Epoch 76/200
# 8/8 [==============================] - 0s 3ms/step - loss: 9.9166 - accuracy: 0.7706
# Epoch 77/200
# 8/8 [==============================] - 0s 3ms/step - loss: 7.5616 - accuracy: 0.8225
# Epoch 78/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.9609 - accuracy: 0.8398
# Epoch 79/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.5610 - accuracy: 0.7359
# Epoch 80/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.3963 - accuracy: 0.7706
# Epoch 81/200
# 8/8 [==============================] - 0s 3ms/step - loss: 8.7683 - accuracy: 0.8182
# Epoch 82/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.8344 - accuracy: 0.7446
# Epoch 83/200
# 8/8 [==============================] - 0s 2ms/step - loss: 10.4710 - accuracy: 0.8095
# Epoch 84/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.3151 - accuracy: 0.8355
# Epoch 85/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.2715 - accuracy: 0.7662
# Epoch 86/200
# 8/8 [==============================] - 0s 2ms/step - loss: 9.6472 - accuracy: 0.8225
# Epoch 87/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.2273 - accuracy: 0.7835
# Epoch 88/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.7068 - accuracy: 0.7749
# Epoch 89/200
# 8/8 [==============================] - 0s 2ms/step - loss: 19.3252 - accuracy: 0.7749
# Epoch 90/200
# 8/8 [==============================] - 0s 2ms/step - loss: 17.9165 - accuracy: 0.7879
# Epoch 91/200
# 8/8 [==============================] - 0s 2ms/step - loss: 15.0716 - accuracy: 0.8139
# Epoch 92/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.1676 - accuracy: 0.8182
# Epoch 93/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.2005 - accuracy: 0.8312
# Epoch 94/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.2497 - accuracy: 0.8398
# Epoch 95/200
# 8/8 [==============================] - ETA: 0s - loss: 5.8579 - accuracy: 0.81 - 0s 2ms/step - loss: 8.1707 - accuracy: 0.8615
# Epoch 96/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.7833 - accuracy: 0.8182
# Epoch 97/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.2228 - accuracy: 0.8528
# Epoch 98/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.3036 - accuracy: 0.7706
# Epoch 99/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.6596 - accuracy: 0.7922
# Epoch 100/200
# 8/8 [==============================] - 0s 2ms/step - loss: 11.6562 - accuracy: 0.7143
# Epoch 101/200
# 8/8 [==============================] - 0s 2ms/step - loss: 15.5058 - accuracy: 0.8571
# Epoch 102/200
# 8/8 [==============================] - 0s 2ms/step - loss: 12.8933 - accuracy: 0.8139
# Epoch 103/200
# 8/8 [==============================] - 0s 2ms/step - loss: 12.8076 - accuracy: 0.8398
# Epoch 104/200
# 8/8 [==============================] - 0s 2ms/step - loss: 9.3864 - accuracy: 0.8312
# Epoch 105/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.5610 - accuracy: 0.7792
# Epoch 106/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.5787 - accuracy: 0.8571
# Epoch 107/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.4835 - accuracy: 0.8268
# Epoch 108/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.1196 - accuracy: 0.8268
# Epoch 109/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.5864 - accuracy: 0.8615
# Epoch 110/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.3635 - accuracy: 0.7576
# Epoch 111/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.0496 - accuracy: 0.7965
# Epoch 112/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.5038 - accuracy: 0.8139
# Epoch 113/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.9898 - accuracy: 0.8398
# Epoch 114/200
# 8/8 [==============================] - 0s 5ms/step - loss: 4.1264 - accuracy: 0.8009
# Epoch 115/200
# 8/8 [==============================] - 0s 9ms/step - loss: 9.4425 - accuracy: 0.6926
# Epoch 116/200
# 8/8 [==============================] - 0s 3ms/step - loss: 8.0549 - accuracy: 0.7706
# Epoch 117/200
# 8/8 [==============================] - 0s 4ms/step - loss: 5.7685 - accuracy: 0.8225
# Epoch 118/200
# 8/8 [==============================] - 0s 5ms/step - loss: 5.8962 - accuracy: 0.7619
# Epoch 119/200
# 8/8 [==============================] - 0s 4ms/step - loss: 15.6229 - accuracy: 0.7143
# Epoch 120/200
# 8/8 [==============================] - 0s 3ms/step - loss: 15.8582 - accuracy: 0.8658
# Epoch 121/200
# 8/8 [==============================] - 0s 3ms/step - loss: 9.3897 - accuracy: 0.7965
# Epoch 122/200
# 8/8 [==============================] - 0s 3ms/step - loss: 9.5170 - accuracy: 0.7576
# Epoch 123/200
# 8/8 [==============================] - 0s 3ms/step - loss: 13.1690 - accuracy: 0.7965
# Epoch 124/200
# 8/8 [==============================] - 0s 3ms/step - loss: 8.7388 - accuracy: 0.8052
# Epoch 125/200
# 8/8 [==============================] - 0s 3ms/step - loss: 10.6846 - accuracy: 0.8355
# Epoch 126/200
# 8/8 [==============================] - 0s 3ms/step - loss: 8.8000 - accuracy: 0.7576
# Epoch 127/200
# 8/8 [==============================] - 0s 3ms/step - loss: 7.6937 - accuracy: 0.8485
# Epoch 128/200
# 8/8 [==============================] - 0s 3ms/step - loss: 10.5039 - accuracy: 0.8658
# Epoch 129/200
# 8/8 [==============================] - 0s 3ms/step - loss: 8.6036 - accuracy: 0.7619
# Epoch 130/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.9289 - accuracy: 0.8139
# Epoch 131/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.1515 - accuracy: 0.8225
# Epoch 132/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.2158 - accuracy: 0.7489
# Epoch 133/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.1925 - accuracy: 0.7965
# Epoch 134/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.7236 - accuracy: 0.8355
# Epoch 135/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.7473 - accuracy: 0.8052
# Epoch 136/200
# 8/8 [==============================] - 0s 3ms/step - loss: 8.1482 - accuracy: 0.7965
# Epoch 137/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.4510 - accuracy: 0.7749
# Epoch 138/200
# 8/8 [==============================] - 0s 3ms/step - loss: 6.8393 - accuracy: 0.7835
# Epoch 139/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.0554 - accuracy: 0.8528
# Epoch 140/200
# 8/8 [==============================] - 0s 3ms/step - loss: 12.7124 - accuracy: 0.6710
# Epoch 141/200
# 8/8 [==============================] - 0s 2ms/step - loss: 16.5541 - accuracy: 0.8052
# Epoch 142/200
# 8/8 [==============================] - 0s 3ms/step - loss: 10.4795 - accuracy: 0.7835
# Epoch 143/200
# 8/8 [==============================] - 0s 3ms/step - loss: 10.5320 - accuracy: 0.8528
# Epoch 144/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.9493 - accuracy: 0.7792
# Epoch 145/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.6596 - accuracy: 0.8139
# Epoch 146/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.9590 - accuracy: 0.8095
# Epoch 147/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.5319 - accuracy: 0.8571
# Epoch 148/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.3595 - accuracy: 0.8398
# Epoch 149/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.5065 - accuracy: 0.8355
# Epoch 150/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9898 - accuracy: 0.8355
# Epoch 151/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.6832 - accuracy: 0.7619
# Epoch 152/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.2431 - accuracy: 0.7100
# Epoch 153/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.8674 - accuracy: 0.8009
# Epoch 154/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.4547 - accuracy: 0.8355
# Epoch 155/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.1336 - accuracy: 0.8268
# Epoch 156/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.2359 - accuracy: 0.8745
# Epoch 157/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5772 - accuracy: 0.8052
# Epoch 158/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.7457 - accuracy: 0.8701
# Epoch 159/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.1713 - accuracy: 0.8485
# Epoch 160/200
# 8/8 [==============================] - 0s 3ms/step - loss: 7.8844 - accuracy: 0.6926
# Epoch 161/200
# 8/8 [==============================] - 0s 3ms/step - loss: 7.4565 - accuracy: 0.7922
# Epoch 162/200
# 8/8 [==============================] - 0s 3ms/step - loss: 7.7786 - accuracy: 0.7576
# Epoch 163/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.1372 - accuracy: 0.8225
# Epoch 164/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.9485 - accuracy: 0.7835
# Epoch 165/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.2829 - accuracy: 0.8442
# Epoch 166/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.6002 - accuracy: 0.7706
# Epoch 167/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.0233 - accuracy: 0.8268
# Epoch 168/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.0767 - accuracy: 0.8442
# Epoch 169/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4551 - accuracy: 0.7446
# Epoch 170/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.5349 - accuracy: 0.8312
# Epoch 171/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1307 - accuracy: 0.8009
# Epoch 172/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.2003 - accuracy: 0.8442
# Epoch 173/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.7881 - accuracy: 0.8182
# Epoch 174/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.4347 - accuracy: 0.7749
# Epoch 175/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.7091 - accuracy: 0.7706
# Epoch 176/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.8015 - accuracy: 0.8095
# Epoch 177/200
# 8/8 [==============================] - 0s 3ms/step - loss: 5.5569 - accuracy: 0.7965
# Epoch 178/200
# 8/8 [==============================] - 0s 3ms/step - loss: 5.4144 - accuracy: 0.8268
# Epoch 179/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.4923 - accuracy: 0.7922
# Epoch 180/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.8013 - accuracy: 0.8355
# Epoch 181/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.0680 - accuracy: 0.8052
# Epoch 182/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.2808 - accuracy: 0.8528
# Epoch 183/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.5578 - accuracy: 0.8139
# Epoch 184/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.4108 - accuracy: 0.8831
# Epoch 185/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.0698 - accuracy: 0.8658
# Epoch 186/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.4700 - accuracy: 0.7792
# Epoch 187/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.8964 - accuracy: 0.8485
# Epoch 188/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.0651 - accuracy: 0.8095
# Epoch 189/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9190 - accuracy: 0.8788
# Epoch 190/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4881 - accuracy: 0.8745
# Epoch 191/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.0888 - accuracy: 0.8658
# Epoch 192/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9543 - accuracy: 0.7706
# Epoch 193/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.6735 - accuracy: 0.8874
# Epoch 194/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.2099 - accuracy: 0.8225
# Epoch 195/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4993 - accuracy: 0.9091
# Epoch 196/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3791 - accuracy: 0.8442
# Epoch 197/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2804 - accuracy: 0.8528
# Epoch 198/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2966 - accuracy: 0.7576
# Epoch 199/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.1082 - accuracy: 0.8788
# Epoch 200/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0481 - accuracy: 0.7749
# Model#: 6.3.1
#  Neural Network (midi and wav data)
#  Test Set F1-score: 80.10%

# %% [markdown]
# ### Observation : Cases removed through SMOTE run on the training data will not be classified correctly in the test data step subsequently in the Model Test Set Evaluation.ipynb file .

# %% [markdown]
# # Development Results
# |       | Model               | Model Variant                                           | Feature Set | Max CV F1 Score | Mean CV F1 Score |
# |-------|---------------------|---------------------------------------------------------|-------------|-----------------|------------------|
# | 1.1.1 | Logistic Regression | Baseline                                                | Spectral    | 97.6%           | 94.4%            |
# | 1.1.2 | Logistic Regression | w/PCA                                                   | Spectral    | 63.6%           | 59.2%            |
# | 1.2.1 | Logistic Regression | Baseline                                                | Midi        | 69.6%           | 65.0%            |
# | 1.2.2 | Logistic Regression | w/PCA                                                   | Midi        | 31.2%           | 27.4%            |
# | 1.3.1 | Logistic Regression | Baseline                                                | Combined    | 91.4%           | 82.4%            |
# | 1.3.2 | Logistic Regression | w/PCA                                                   | Combined    | 31.2%           | 29.9%            |
# | 2.1.1 | Naive Bayes         | Baseline                                                | Spectral    | 70.9%           | 66.7%            |
# | 2.2.1 | Naive Bayes         | Baseline                                                | Midi        | 75.8%           | 58.9%            |
# | 2.3.1 | Naive Bayes         | Baseline                                                | Combined    | 76.8%           | 74.3%            |
# | 3.1.1 | Decision Tree       | Baseline                                                | Spectral    | 75.7%           | 71.4%            |
# | 3.2.1 | Decision Tree       | Baseline                                                | Midi        | 84.8%           | 82.5%            |
# | 3.3.1 | Decision Tree       | Baseline                                                | Combined    | 91.8%           | 81.4%            |
# | 4.1.1 | Random Forest       | Baseline                                                | Spectral    | 83.9%           | 78.6%            |
# | 4.1.2 | Random Forest       | w/SMOTE                                                 | Spectral    | 100%            | 99.6%            |
# | 4.2.1 | Random Forest       | Baseline                                                | Midi        | 92.7%           | 87.5%            |
# | 4.2.2 | Random Forest       | w/SMOTE                                                 | Midi        | 99.6%           | 99.4%            |
# | 4.3.1 | Random Forest       | Baseline                                                | Combined    | 91.3%           | 82.9%            |
# | 4.3.2 | Random Forest       | w/SMOTE                                                 | Combined    | 100%            | 99.3%            |
# | 5.1.1 | SVM                 | Baseline                                                | Spectral    | 57.6%           | 54.2%            |
# | 5.1.2 | SVM                 | w/Hyperparameter Tuning                                 | Spectral    | 94.6%           | 90.4%            |
# | 5.1.3 | SVM                 | w/Hyperparameter Tuning +  PCA                          | Spectral    | 91.5%           | 89.1%            |
# | 5.1.4 | SVM                 | w/Hyperparameter Tuning +  PCA + SMOTE                  | Spectral    | 100%            | 99.4%            |
# | 5.1.5 | SVM                 | w/Hyperparameter Tuning +  PCA + SMOTE + MinMaxScaler   | Spectral    | 75.5%           | 70.2%            |
# | 5.1.6 | SVM                 | w/Hyperparameter Tuning +  PCA + SMOTE + StandardScaler | Spectral    | 97.3%           | 96.3%            |
# | 5.2.1 | SVM                 | Baseline                                                | Midi        | 65.6%           | 64.1%            |
# | 5.3.1 | SVM                 | Baseline                                                | Combined    | 65.6%           | 64.0%            |
# | 6.1.1 | Neural Network      | Baseline (ADAM,  5 Hidden Layers)                       | Spectral    |                 | 100%             |
# | 6.2.1 | Neural Network      | Baseline (ADAM,  5 Hidden Layers)                       | Midi        |                 | 80.8%            |
# | 6.3.1 | Neural Network      | Baseline (ADAM,  5 Hidden Layers)                       | Combined    |                 | 81.2%            |

# %% [markdown]
# The Top 10 model-data combinations with the highest accuracy during cross-validation were
# 1. Neural Network - Spectral
# 2. Neural Network - Midi
# 3. Random Forest w/SMOTE - Spectral
# 4. Random Forest w/SMOTE - Midi
# 5. Random Forest w/SMOTE - Combined
# 6. SVM w/Hyper Parameter Tuning + PCA + SMOTE - Spectral
# 7. Random Forest - Midi
# 8. SVM w/Hyper Parameter Tuning + PCA + SMOTE + StandardScaler - Spectral
# 9. Logistic Regression - Spectral
# 10. Logistic Regression - Combined

# %% [markdown]
# # Conclusion on Cross-Validated Results on Development Set :
#
# #### First, we discuss the cross-validation results with respect to the business use case on Spectral Features from WAV Files.
# - This is the type of data that will most likely be encountered in a business context and in practice (e.g. for a music playlist application) compared to MIDI data which is labelled.
# - We selected F1-Score as the evaluation criterion for our project because it is incorporates prediction error on imbalanced datasets.
#     - We can see that the Top 3 Models using Spectral Data are :
#             (1) Neural Networks (Full Connected with 5 HiddenLayers and Adam Optimizer) with 100% F1 Score
#             (2) Random Forest with SMOTE (Sample Balancing) with 99.6% F1 Score
#             (3) SVM (with PCA and SMOTE) with 99.4% F1 Score
#
# Most other models had F1 Scores above 65%. This gives us confidence to proceed to the next step of validating on the test set. We think our models did reasonably well because the sampling balancing algorithm generated more data for the models to train on for classification.

# %% [markdown]
#
# #### In the second part of this discussion, we look at the results on MIDI data.
# - We know from the Random Forest Analysis that the single most important variable in the MIDI data is the number of unique instruments in the song.
# - However, we think such data is less likely to be available in a business context due to cost reasons of manually labelling data.
# - The results discussed here are more applicable for academic purposes - for e.g. How well could a model perform with manually labelled data if there were resources to do so for example at a school?
# - The use case of such data could be an application for music students to learn and differentiate between ensembles.
# - MIDI labels were likely manually created by the data creators by writing into a Music Sheet Program and then converted to MIDI.
#     - We see that the Top Model for MIDI data is :
#             (1) Random Forest with SMOTE with F1 Score of 99.4%.
#
#
# Some models struggled with classifying the MIDI data. For example, SVM - one clue is that the best C value for SVM is extremely high at 10,000. In other words, very low regularization strength and extreme overfitting is required to fit the model well.

# %% [markdown]
# #### Lastly, for academic purposes - we wanted to see how the model would perform on both typical Spectral data seen in a business context combined with manually labelled MIDI data.
#     - Again here, we see that the Top Model for Combined MIDI and Wav Spectral Data is Random Forest with SMOTE at 99.3%.
#
# We conclude that the results on Spectral Data are very promising and we proceed to validate model performance on test data in our next notebook step "Model Test Evaluation.ipynb"
