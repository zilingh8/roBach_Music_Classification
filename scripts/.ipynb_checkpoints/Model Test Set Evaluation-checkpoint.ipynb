# %% [markdown]
# # Test Set Evaluation of Top Performing Models
#
# ## Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt   
# %matplotlib inline
from music21 import *
from IPython.display import Audio
from intervaltree import Interval,IntervalTree
import pandas as pd
import seaborn as sns

from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
import sklearn.model_selection as model_selection
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.metrics import classification_report
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

from collections import Counter
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# ### Import spectral csv features which were extracted from earlier Data PreProcessing notebook

# %%
X_train_w = pd.read_csv('../data/X_train_w.csv',index_col = 0)
X_test_w = pd.read_csv('../data/X_test_w.csv',index_col = 0)
y_train_w = pd.read_csv('../data/y_train_w.csv',index_col = 0)
y_test_w = pd.read_csv('../data/y_test_w.csv',index_col = 0)

# %% [markdown]
# # Development Results
# |       | Model               | Model Variant                                           | Feature Set | Max CV F1 Score | Mean CV F1 Score |
# |-------|---------------------|---------------------------------------------------------|-------------|-----------------|------------------|
# | 1.1.1 | Logistic Regression | Baseline                                                | Spectral    | 97.6%           | 94.4%            |
# | 1.1.2 | Logistic Regression | w/PCA                                                   | Spectral    | 63.6%           | 59.2%            |
# | 1.2.1 | Logistic Regression | Baseline                                                | Midi        | 69.6%           | 65.0%            |
# | 1.2.2 | Logistic Regression | w/PCA                                                   | Midi        | 31.2%           | 27.4%            |
# | 1.3.1 | Logistic Regression | Baseline                                                | Combined    | 91.4%           | 82.4%            |
# | 1.3.2 | Logistic Regression | w/PCA                                                   | Combined    | 31.2%           | 29.9%            |
# | 2.1.1 | Naive Bayes         | Baseline                                                | Spectral    | 70.9%           | 66.7%            |
# | 2.2.1 | Naive Bayes         | Baseline                                                | Midi        | 75.8%           | 58.9%            |
# | 2.3.1 | Naive Bayes         | Baseline                                                | Combined    | 76.8%           | 74.3%            |
# | 3.1.1 | Decision Tree       | Baseline                                                | Spectral    | 75.7%           | 71.4%            |
# | 3.2.1 | Decision Tree       | Baseline                                                | Midi        | 84.8%           | 82.5%            |
# | 3.3.1 | Decision Tree       | Baseline                                                | Combined    | 91.8%           | 81.4%            |
# | 4.1.1 | Random Forest       | Baseline                                                | Spectral    | 83.9%           | 78.6%            |
# | 4.1.2 | Random Forest       | w/SMOTE                                                 | Spectral    | 100%            | 99.6%            |
# | 4.2.1 | Random Forest       | Baseline                                                | Midi        | 92.7%           | 87.5%            |
# | 4.2.2 | Random Forest       | w/SMOTE                                                 | Midi        | 99.6%           | 99.4%            |
# | 4.3.1 | Random Forest       | Baseline                                                | Combined    | 91.3%           | 82.9%            |
# | 4.3.2 | Random Forest       | w/SMOTE                                                 | Combined    | 100%            | 99.3%            |
# | 5.1.1 | SVM                 | Baseline                                                | Spectral    | 57.6%           | 54.2%            |
# | 5.1.2 | SVM                 | w/Hyperparameter Tuning                                 | Spectral    | 94.6%           | 90.4%            |
# | 5.1.3 | SVM                 | w/Hyperparameter Tuning +  PCA                          | Spectral    | 91.5%           | 89.1%            |
# | 5.1.4 | SVM                 | w/Hyperparameter Tuning +  PCA + SMOTE                  | Spectral    | 100%            | 99.4%            |
# | 5.1.5 | SVM                 | w/Hyperparameter Tuning +  PCA + SMOTE + MinMaxScaler   | Spectral    | 75.5%           | 70.2%            |
# | 5.1.6 | SVM                 | w/Hyperparameter Tuning +  PCA + SMOTE + StandardScaler | Spectral    | 97.3%           | 96.3%            |
# | 5.2.1 | SVM                 | Baseline                                                | Midi        | 65.6%           | 64.1%            |
# | 5.3.1 | SVM                 | Baseline                                                | Combined    | 65.6%           | 64.0%            |
# | 6.1.1 | Neural Network      | Baseline (ADAM,  5 Hidden Layers)                       | Spectral    |                 | 100%             |
# | 6.2.1 | Neural Network      | Baseline (ADAM,  5 Hidden Layers)                       | Midi        |                 | 80.8%            |
# | 6.3.1 | Neural Network      | Baseline (ADAM,  5 Hidden Layers)                       | Combined    |                 | 81.2%            |

# %% [markdown]
# ## Spectral Models by Development Score
# |       |               Model |                                          Model Variant | Mean CV F1 Score |
# |-------|--------------------:|-------------------------------------------------------:|-----------------:|
# | 6.1.1 |      Neural Network |                       Baseline (ADAM, 5 Hidden Layers) |             100% |
# | 4.1.2 |       Random Forest |                                                w/SMOTE |           99.60% |
# | 5.1.4 |                 SVM |                  w/Hyperparameter Tuning + PCA + SMOTE |           99.40% |
# | 5.1.6 |                 SVM | w/Hyperparameter Tuning + PCA + SMOTE + StandardScaler |           96.30% |
# | 1.1.1 | Logistic Regression |                                               Baseline |           94.40% |
# | 5.1.2 |                 SVM |                                w/Hyperparameter Tuning |           90.40% |
# | 5.1.3 |                 SVM |                          w/Hyperparameter Tuning + PCA |           89.10% |
# | 4.1.1 |       Random Forest |                                               Baseline |           78.60% |
# | 3.1.1 |       Decision Tree |                                               Baseline |           71.40% |
# | 5.1.5 |                 SVM |   w/Hyperparameter Tuning + PCA + SMOTE + MinMaxScaler |           70.20% |
# | 2.1.1 |         Naive Bayes |                                               Baseline |           66.70% |
# | 1.1.2 | Logistic Regression |                                                  w/PCA |           59.20% |
# | 5.1.1 |                 SVM |                                               Baseline |           54.20% |

# %% [markdown]
# #### Set Random Seed

# %%
from numpy.random import seed
seed(1)
from tensorflow.random import set_seed
set_seed(2)

# %% [markdown]
# ### Neural Network - Baseline

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(176, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(90, activation='relu'),
    tf.keras.layers.Dense(80, activation='relu'),
    tf.keras.layers.Dense(70, activation='relu'),
    tf.keras.layers.Dense(60, activation='relu'),
    tf.keras.layers.Dense(21)
])
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
history = model.fit(X_train_w, y_train_w, epochs=200)
predictions = model.predict(X_test_w)
preds = []
for i in predictions:
    preds.append(np.where(i == i.max())[0][0])
preds
f1 = f1_score(y_test_w, preds, average='weighted')
output_file = open('../output/test_set_output', 'a')
model_no = 'Model #: 1\n'
model_type = 'Neural Network Baseline (wav data only)\n'
model_scores = f'F1 Score: {f1}\n'
output_file.writelines([model_no, model_type, model_scores])
output_file.close()

print('Test Set F1 score = {:.2%}'.format(f1))
# Out:
# Epoch 1/200
# 9/9 [==============================] - 2s 3ms/step - loss: 4.5076 - accuracy: 0.3688
# Epoch 2/200
# 9/9 [==============================] - 0s 8ms/step - loss: 2.0893 - accuracy: 0.4981
# Epoch 3/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1.6749 - accuracy: 0.5627
# Epoch 4/200
# 9/9 [==============================] - 0s 4ms/step - loss: 1.5350 - accuracy: 0.6008
# Epoch 5/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1.3217 - accuracy: 0.6540
# Epoch 6/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1.1908 - accuracy: 0.6920
# Epoch 7/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0166 - accuracy: 0.7452
# Epoch 8/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9066 - accuracy: 0.7300
# Epoch 9/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8002 - accuracy: 0.7643
# Epoch 10/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.7068 - accuracy: 0.7833
# Epoch 11/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.7128 - accuracy: 0.7909
# Epoch 12/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6821 - accuracy: 0.7909
# Epoch 13/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5918 - accuracy: 0.8327
# Epoch 14/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5826 - accuracy: 0.8251
# Epoch 15/200
# 9/9 [==============================] - 0s 26ms/step - loss: 0.7373 - accuracy: 0.7719
# Epoch 16/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.5777 - accuracy: 0.8175
# Epoch 17/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.5818 - accuracy: 0.8327
# Epoch 18/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4563 - accuracy: 0.8479
# Epoch 19/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4127 - accuracy: 0.87 - 0s 13ms/step - loss: 0.4083 - accuracy: 0.8745
# Epoch 20/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3589 - accuracy: 0.8859
# Epoch 21/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3375 - accuracy: 0.8897
# Epoch 22/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4259 - accuracy: 0.8555
# Epoch 23/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3604 - accuracy: 0.8821
# Epoch 24/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3021 - accuracy: 0.9049
# Epoch 25/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2400 - accuracy: 0.9087
# Epoch 26/200
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2205 - accuracy: 0.9163
# Epoch 27/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2478 - accuracy: 0.9125
# Epoch 28/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1961 - accuracy: 0.9430
# Epoch 29/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1789 - accuracy: 0.9468
# Epoch 30/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1872 - accuracy: 0.9354
# Epoch 31/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3245 - accuracy: 0.8935
# Epoch 32/200
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3229 - accuracy: 0.8935
# Epoch 33/200
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1999 - accuracy: 0.9430
# Epoch 34/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2616 - accuracy: 0.9125
# Epoch 35/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4908 - accuracy: 0.8479
# Epoch 36/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5785 - accuracy: 0.8061
# Epoch 37/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3446 - accuracy: 0.8973
# Epoch 38/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2897 - accuracy: 0.9049
# Epoch 39/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2225 - accuracy: 0.9278
# Epoch 40/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2084 - accuracy: 0.9163
# Epoch 41/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2314 - accuracy: 0.8973
# Epoch 42/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2341 - accuracy: 0.9354
# Epoch 43/200
# 9/9 [==============================] - 0s 22ms/step - loss: 0.1525 - accuracy: 0.9620
# Epoch 44/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1659 - accuracy: 0.9316
# Epoch 45/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0841 - accuracy: 0.9772
# Epoch 46/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0939 - accuracy: 0.9620
# Epoch 47/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1408 - accuracy: 0.9468
# Epoch 48/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2389 - accuracy: 0.9125
# Epoch 49/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2767 - accuracy: 0.8973
# Epoch 50/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1505 - accuracy: 0.9620
# Epoch 51/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0959 - accuracy: 0.9848
# Epoch 52/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0964 - accuracy: 0.9658
# Epoch 53/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0533 - accuracy: 1.0000
# Epoch 54/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0650 - accuracy: 0.9772 0s - loss: 0.0726 - accuracy: 0.97
# Epoch 55/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 1.00 - 0s 13ms/step - loss: 0.0457 - accuracy: 0.9962
# Epoch 56/200
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0462 - accuracy: 0.9810
# Epoch 57/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0360 - accuracy: 0.9924
# Epoch 58/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0251 - accuracy: 0.9962
# Epoch 59/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0232 - accuracy: 0.9962
# Epoch 60/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0205 - accuracy: 0.9962
# Epoch 61/200
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 62/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 0.9962
# Epoch 63/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0164 - accuracy: 0.9962
# Epoch 64/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 65/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 66/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 67/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 68/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 69/200
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 70/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 71/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 72/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 73/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 74/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 75/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 76/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 77/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 78/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 79/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 80/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 1.00 - 0s 5ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 81/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 82/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 83/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 84/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 85/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 86/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 87/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 88/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 89/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 90/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 91/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 92/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 93/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 94/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 95/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 96/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 97/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 98/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 99/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 100/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 101/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 102/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 103/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 104/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 105/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 106/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 107/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0220 - accuracy: 0.9886
# Epoch 108/200
# 9/9 [==============================] - ETA: 0s - loss: 5.9136e-04 - accuracy: 1.00 - 0s 5ms/step - loss: 0.1068 - accuracy: 0.9658
# Epoch 109/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2093 - accuracy: 0.9506
# Epoch 110/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5130 - accuracy: 0.8479
# Epoch 111/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2974 - accuracy: 0.9011
# Epoch 112/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2014 - accuracy: 0.9354
# Epoch 113/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2879 - accuracy: 0.9087
# Epoch 114/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0903 - accuracy: 0.9696
# Epoch 115/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1191 - accuracy: 0.9620
# Epoch 116/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0946 - accuracy: 0.9696
# Epoch 117/200
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1077 - accuracy: 0.9620
# Epoch 118/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1443 - accuracy: 0.9544
# Epoch 119/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1100 - accuracy: 0.9544
# Epoch 120/200
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1157 - accuracy: 0.9696
# Epoch 121/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0529 - accuracy: 0.9848
# Epoch 122/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0556 - accuracy: 0.9810
# Epoch 123/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0549 - accuracy: 0.9924
# Epoch 124/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0485 - accuracy: 0.9848
# Epoch 125/200
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0209 - accuracy: 0.9962
# Epoch 126/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0235 - accuracy: 0.9962
# Epoch 127/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 128/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 129/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 130/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 1.00 - 0s 11ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 131/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 132/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 133/200
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 134/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 135/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 136/200
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 137/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 138/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 139/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 140/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 141/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 142/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 143/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 144/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 145/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 146/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 147/200
# 9/9 [==============================] - 0s 5ms/step - loss: 9.8497e-04 - accuracy: 1.0000
# Epoch 148/200
# 9/9 [==============================] - 0s 6ms/step - loss: 9.6650e-04 - accuracy: 1.0000
# Epoch 149/200
# 9/9 [==============================] - 0s 8ms/step - loss: 9.4106e-04 - accuracy: 1.0000
# Epoch 150/200
# 9/9 [==============================] - 0s 6ms/step - loss: 9.1521e-04 - accuracy: 1.0000
# Epoch 151/200
# 9/9 [==============================] - 0s 5ms/step - loss: 8.7506e-04 - accuracy: 1.0000
# Epoch 152/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.4564e-04 - accuracy: 1.0000
# Epoch 153/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.4315e-04 - accuracy: 1.0000
# Epoch 154/200
# 9/9 [==============================] - 0s 5ms/step - loss: 8.1372e-04 - accuracy: 1.0000
# Epoch 155/200
# 9/9 [==============================] - 0s 5ms/step - loss: 7.8554e-04 - accuracy: 1.0000
# Epoch 156/200
# 9/9 [==============================] - 0s 6ms/step - loss: 7.5927e-04 - accuracy: 1.0000
# Epoch 157/200
# 9/9 [==============================] - 0s 11ms/step - loss: 7.4387e-04 - accuracy: 1.0000
# Epoch 158/200
# 9/9 [==============================] - 0s 5ms/step - loss: 7.2519e-04 - accuracy: 1.0000
# Epoch 159/200
# 9/9 [==============================] - 0s 6ms/step - loss: 7.2650e-04 - accuracy: 1.0000
# Epoch 160/200
# 9/9 [==============================] - 0s 9ms/step - loss: 7.0670e-04 - accuracy: 1.0000
# Epoch 161/200
# 9/9 [==============================] - 0s 6ms/step - loss: 6.7622e-04 - accuracy: 1.0000
# Epoch 162/200
# 9/9 [==============================] - 0s 6ms/step - loss: 6.4874e-04 - accuracy: 1.0000
# Epoch 163/200
# 9/9 [==============================] - 0s 8ms/step - loss: 6.3940e-04 - accuracy: 1.0000
# Epoch 164/200
# 9/9 [==============================] - 0s 6ms/step - loss: 6.3291e-04 - accuracy: 1.0000
# Epoch 165/200
# 9/9 [==============================] - 0s 5ms/step - loss: 6.2023e-04 - accuracy: 1.0000
# Epoch 166/200
# 9/9 [==============================] - 0s 10ms/step - loss: 6.0183e-04 - accuracy: 1.0000
# Epoch 167/200
# 9/9 [==============================] - 0s 5ms/step - loss: 5.8356e-04 - accuracy: 1.0000
# Epoch 168/200
# 9/9 [==============================] - 0s 7ms/step - loss: 5.6746e-04 - accuracy: 1.0000
# Epoch 169/200
# 9/9 [==============================] - 0s 8ms/step - loss: 5.5450e-04 - accuracy: 1.0000
# Epoch 170/200
# 9/9 [==============================] - 0s 5ms/step - loss: 5.4412e-04 - accuracy: 1.0000
# Epoch 171/200
# 9/9 [==============================] - 0s 5ms/step - loss: 5.2510e-04 - accuracy: 1.0000
# Epoch 172/200
# 9/9 [==============================] - 0s 8ms/step - loss: 5.2849e-04 - accuracy: 1.0000
# Epoch 173/200
# 9/9 [==============================] - 0s 8ms/step - loss: 5.1389e-04 - accuracy: 1.0000
# Epoch 174/200
# 9/9 [==============================] - 0s 7ms/step - loss: 4.9650e-04 - accuracy: 1.0000
# Epoch 175/200
# 9/9 [==============================] - 0s 5ms/step - loss: 4.8234e-04 - accuracy: 1.0000
# Epoch 176/200
# 9/9 [==============================] - 0s 10ms/step - loss: 4.7044e-04 - accuracy: 1.0000
# Epoch 177/200
# 9/9 [==============================] - 0s 6ms/step - loss: 4.7843e-04 - accuracy: 1.0000
# Epoch 178/200
# 9/9 [==============================] - 0s 5ms/step - loss: 4.5472e-04 - accuracy: 1.0000
# Epoch 179/200
# 9/9 [==============================] - 0s 11ms/step - loss: 4.3251e-04 - accuracy: 1.0000
# Epoch 180/200
# 9/9 [==============================] - 0s 10ms/step - loss: 4.2366e-04 - accuracy: 1.0000
# Epoch 181/200
# 9/9 [==============================] - 0s 5ms/step - loss: 4.1408e-04 - accuracy: 1.0000
# Epoch 182/200
# 9/9 [==============================] - 0s 8ms/step - loss: 4.0529e-04 - accuracy: 1.0000
# Epoch 183/200
# 9/9 [==============================] - 0s 8ms/step - loss: 4.0332e-04 - accuracy: 1.0000
# Epoch 184/200
# 9/9 [==============================] - 0s 5ms/step - loss: 3.9305e-04 - accuracy: 1.0000
# Epoch 185/200
# 9/9 [==============================] - 0s 5ms/step - loss: 3.9192e-04 - accuracy: 1.0000
# Epoch 186/200
# 9/9 [==============================] - 0s 5ms/step - loss: 3.8168e-04 - accuracy: 1.0000
# Epoch 187/200
# 9/9 [==============================] - 0s 6ms/step - loss: 3.7213e-04 - accuracy: 1.0000
# Epoch 188/200
# 9/9 [==============================] - 0s 6ms/step - loss: 3.6269e-04 - accuracy: 1.0000
# Epoch 189/200
# 9/9 [==============================] - 0s 8ms/step - loss: 3.5874e-04 - accuracy: 1.0000
# Epoch 190/200
# 9/9 [==============================] - 0s 8ms/step - loss: 3.4978e-04 - accuracy: 1.0000
# Epoch 191/200
# 9/9 [==============================] - 0s 7ms/step - loss: 3.3964e-04 - accuracy: 1.0000
# Epoch 192/200
# 9/9 [==============================] - 0s 6ms/step - loss: 3.4418e-04 - accuracy: 1.0000
# Epoch 193/200
# 9/9 [==============================] - 0s 7ms/step - loss: 3.3191e-04 - accuracy: 1.0000
# Epoch 194/200
# 9/9 [==============================] - 0s 7ms/step - loss: 3.2107e-04 - accuracy: 1.0000
# Epoch 195/200
# 9/9 [==============================] - 0s 5ms/step - loss: 3.1497e-04 - accuracy: 1.0000
# Epoch 196/200
# 9/9 [==============================] - 0s 9ms/step - loss: 3.1043e-04 - accuracy: 1.0000
# Epoch 197/200
# 9/9 [==============================] - 0s 6ms/step - loss: 3.0215e-04 - accuracy: 1.0000
# Epoch 198/200
# 9/9 [==============================] - 0s 9ms/step - loss: 3.0831e-04 - accuracy: 1.0000
# Epoch 199/200
# 9/9 [==============================] - 0s 7ms/step - loss: 2.9969e-04 - accuracy: 1.0000
# Epoch 200/200
# 9/9 [==============================] - 0s 6ms/step - loss: 2.9596e-04 - accuracy: 1.0000
# Test Set F1 score = 85.17%

# %%
ensemble_list = ['Piano Quintet','Solo Piano','Piano Trio','String Quartet','Clarinet Quintet','Pairs Clarinet-Horn-Bassoon',
                'Wind Quintet','Accompanied Cello','Accompanied Clarinet','String Sextet',
                'Piano Quartet','Horn Piano Trio','Solo Violin','Solo Flute','Solo Cello','Violin and Harpsichord',
                'Clarinet-Cello-Piano Trio','Accompanied Violin','Wind Octet']
df_cm = pd.DataFrame(confusion_matrix(np.array(y_test_w), preds), index = ensemble_list,
                  columns = ensemble_list)
plt.figure(figsize = (15,9))
plt.title('Confusion Matrix for Neural Network (Baseline)',fontsize=22)
sns.heatmap(df_cm, annot=True)
plt.ylabel('True Labels',fontsize=15)
plt.xlabel('Predicted Labels',fontsize=15)
# plt.savefig('../output/plots/confusion_matrix_heatmap_nn.png')

# %% [markdown]
# #### Error Analysis :
# - In terms of absolute number, one of the most commonly misclassified ensembles was "Accompanied Violin" which comprises violin and piano. These were misclassified as Solo Piano or Piano Trio.
# - Note that due to SMOTE's effect of removing samples with low frequency (<6) in the train set but not modifying the test set, 30% of the misclassifications in the test set were because these had been removed from the train. This is expected and is a reasonable compromise for generating a balanced dataset for training purposes.

# %% [markdown]
# ### Random Forest - w/SMOTE

# %%
# todo: I think we need to re-import the data for this cell, if this is run multiple times then y_train_w gets overwritten
y_train_w = pd.read_csv('../data/y_train_w.csv',index_col = 0)

#Drop any ensemble types with counts below 6. This because Expected n_neighbors <= n_samples,  
#but n_samples = 3, n_neighbors = 6
counts = y_train_w['ensemble'].value_counts()
X_train_w = X_train_w[~y_train_w['ensemble'].isin(counts[counts < 6].index)]
y_train_w = y_train_w[~y_train_w['ensemble'].isin(counts[counts < 6].index)]

# Fit and apply the transform
X_SMOTE_w, y_SMOTE_w = SMOTE(random_state=101).fit_resample(X_train_w, y_train_w)

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=1)
rf.fit(X_SMOTE_w, y_SMOTE_w)
predictions = rf.predict(X_test_w)
f1 = f1_score(y_test_w, predictions, average='weighted')
output_file = open('../output/test_set_output', 'a')
model_no = 'Model #: 2\n'
model_type = 'Random Forest (wav data only)\n'
model_scores = f'F1 Score: {f1}\n'
output_file.writelines([model_no, model_type, model_scores])
output_file.close()

print('Test Set F1 score = {:.2%}'.format(f1))
# Out:
# Test Set F1 score = 69.14%

# %% [markdown]
# ### SVM - w/Hyperparameter Tuning + PCA + SMOTE

# %%
#Drop any ensemble types with counts below 6
counts = y_train_w['ensemble'].value_counts()
X_train_w_smote = X_train_w[~y_train_w['ensemble'].isin(counts[counts < 6].index)]
y_train_w_smote = y_train_w[~y_train_w['ensemble'].isin(counts[counts < 6].index)]

# fit and apply the transform
X_SMOTE, y_SMOTE = SMOTE().fit_resample(X_train_w_smote, y_train_w_smote.values.ravel())

#Perform PCA with 15 components
pca=PCA(n_components = 15)
pca.fit(X_SMOTE)
train_pca_w_smote = pca.transform(X_SMOTE)
X_test_w_pca = pca.transform(X_test_w)


from sklearn.model_selection import GridSearchCV
  
# defining parameter range
param_grid = {'C': np.logspace(-4, 4, 20), 
              'gamma': np.logspace(-3, 2, 6),
              'kernel': ['linear','rbf','poly']} 
  
grid = GridSearchCV(SVC(), param_grid , cv=5)
  
# fitting the model for grid search
grid.fit(train_pca_w_smote, y_SMOTE)

#Create SVM model with best hyperparameters, PCA and SMOTE

svm = make_pipeline(SVC(kernel=grid.best_params_['kernel'], C = grid.best_params_['C'] , gamma=grid.best_params_['gamma']))
svm.fit(train_pca_w_smote, y_SMOTE)
predictions = svm.predict(X_test_w_pca)
f1 = f1_score(y_test_w, predictions, average='weighted')
output_file = open('../output/test_set_output', 'a')
model_no = 'Model #: 3\n'
model_type = 'SVM - Spectral - w/Hyperparameter Tuning + PCA + SMOTE (wav data only)\n'
model_scores = f'F1 Score: {f1}\n'
output_file.writelines([model_no, model_type, model_scores])
output_file.close()

print("Test Set F1-score: {:.2%}".format(f1))
# Out:
# Test Set F1-score: 71.69%

# %% [markdown]
# ### SVM - w/Hyperparameter Tuning + PCA + SMOTE + StandardScaler

# %%
#### Standard Scaler Application

#Perform PCA with 15 components
pca=PCA(n_components = 15)
pca.fit(X_SMOTE)
train_pca_w_smote = pca.transform(X_SMOTE)
X_test_w_pca = pca.transform(X_test_w)


#Create SVM model with best hyperparameters, PCA and SMOTE and StandardScaler

svm = make_pipeline(StandardScaler() ,SVC(kernel=grid.best_params_['kernel'], C = grid.best_params_['C'] , gamma=grid.best_params_['gamma']))
svm.fit(train_pca_w_smote, y_SMOTE)


predictions = svm.predict(X_test_w_pca)
f1 = f1_score(y_test_w, predictions,average='weighted')
output_file = open('../output/test_set_output', 'a')
model_no = 'Model #: 4\n'
model_type = 'SVM - Spectral - w/Hyperparameter Tuning + PCA + SMOTE + StandardScaler (wav data only)\n'
model_scores = f'F1 Score: {f1}\n'
output_file.writelines([model_no, model_type, model_scores])
output_file.close()
print("Test Set F1-score: {:.2%}".format(f1))
# Out:
# Test Set F1-score: 70.35%

# %% [markdown]
# ### Logistic Regression - Baseline

# %%
#Create Baseline Logistic Model
lr = LogisticRegression(C = 0.5, solver='liblinear', multi_class='auto')
lr.fit(np.array(X_train_w), np.array(y_train_w))
predictions = lr.predict(X_test_w)
f1 = f1_score(y_test_w, predictions,average='weighted')
output_file = open('../output/test_set_output', 'a')
model_no = 'Model #: 5\n'
model_type = 'Logistic Regression - Spectral - Baseline (wav data only)\n'
model_scores = f'F1 Score: {f1}\n'
output_file.writelines([model_no, model_type, model_scores])
output_file.close()
print("Test Set F1-score: {:.2%}".format(f1))
# Out:
# Test Set F1-score: 72.76%

# %% [markdown]
# ### SVM - Spectral - w/Hyperparameter Tuning

# %%
#Find best hyperparameters
param_grid = {'C': np.logspace(-4, 4, 20), 
              'gamma': np.logspace(-3, 2, 6),                     
              'kernel': ['linear','rbf','poly']} 
  
grid = GridSearchCV(SVC(), param_grid, cv=5)
  
# fitting the model for grid search
grid.fit(X_train_w, y_train_w.values.ravel())

#Create Model with best hyperparameters

svm = make_pipeline(SVC(kernel=grid.best_params_['kernel'], C = grid.best_params_['C'] , gamma=grid.best_params_['gamma']))
svm.fit(X_train_w, y_train_w.values.ravel())
predictions = svm.predict(X_test_w)
f1 = f1_score(y_test_w, predictions,average='weighted')
output_file = open('../output/test_set_output', 'a')
model_no = 'Model #: 6\n'
model_type = 'SVM - Spectral - w/Hyperparameter Tuning (wav data only)\n'
model_scores = f'F1 Score: {f1}\n'
output_file.writelines([model_no, model_type, model_scores])
output_file.close()
print("Test Set F1-score: {:.2%}".format(f1))
# Out:
# Test Set F1-score: 70.17%

# %% [markdown]
# ### SVM - Spectral - W/Hyperparameter Tuning + PCA

# %%
#Perform PCA with 15 components
pca=PCA(n_components = 15)
pca.fit(X_train_w)
train_pca_w = pca.transform(X_train_w)
X_test_w_pca = pca.transform(X_test_w)

from sklearn.model_selection import GridSearchCV
  
# defining parameter range
param_grid = {'C': np.logspace(-4, 4, 20), 
              'gamma': np.logspace(-3, 2, 6),
              'kernel': ['linear','rbf','poly']} 
  
grid = GridSearchCV(SVC(), param_grid , cv=5)
  
# fitting the model for grid search
grid.fit(train_pca_w, y_train_w.values.ravel())

#Create Model with best hyperparameters and PCA
svm = make_pipeline(SVC(kernel=grid.best_params_['kernel'], C = grid.best_params_['C'] , gamma=grid.best_params_['gamma']))
svm.fit(train_pca_w, y_train_w.values.ravel())
predictions = svm.predict(X_test_w_pca)
f1 = f1_score(y_test_w, predictions,average='weighted')
output_file = open('../output/test_set_output', 'a')
model_no = 'Model #: 7\n'
model_type = 'SVM - Spectral - W/Hyperparameter Tuning + PCA (wav data only)\n'
model_scores = f'F1 Score: {f1}\n'
output_file.writelines([model_no, model_type, model_scores])
output_file.close()
print("Test Set F1-score: {:.2%}".format(f1))
# Out:
# Test Set F1-score: 66.30%

# %% [markdown]
# ### Random Forest - Baseline

# %%
rf = RandomForestClassifier()
rf.fit(X_train_w, y_train_w)
predictions = rf.predict(X_test_w)
f1 = f1_score(y_test_w, predictions,average='weighted')
output_file = open('../output/test_set_output', 'a')
model_no = 'Model #: 8\n'
model_type = 'Random Forest - Midi - Baseline (wav data only)\n'
model_scores = f'F1 Score: {f1}\n'
output_file.writelines([model_no, model_type, model_scores])
output_file.close()
print("Test Set F1-score: {:.2%}".format(f1))
# Out:
# Test Set F1-score: 65.93%

# %% [markdown]
# ### Decision Tree - Baseline

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train_w, y_train_w)
predictions = dt.predict(X_test_w)
f1 = f1_score(y_test_w, predictions, average = 'weighted')
output_file = open('../output/test_set_output', 'a')
model_no = 'Model #: 9\n'
model_type = 'Decision Tree Baseline Model (wav data only)\n'
model_scores = f'F1 Score: {f1}\n'
output_file.writelines([model_no, model_type, model_scores])
output_file.close()
print("Test Set F1-score: {:.2%}".format(f1))
# Out:
# Test Set F1-score: 70.82%

# %% [markdown]
# ### SVM - w/Hyperparameter Tuning + PCA + SMOTE + MinMaxScaler

# %%
#### MinMaxScaler Application

#Perform PCA with 15 components
pca=PCA(n_components = 15)
pca.fit(X_SMOTE)
train_pca_w_smote = pca.transform(X_SMOTE)
X_test_w_pca = pca.transform(X_test_w)


#Create SVM model with best hyperparameters, PCA and SMOTE and MinMaxScaler

svm = make_pipeline(MinMaxScaler() ,SVC(kernel=grid.best_params_['kernel'], C = grid.best_params_['C'] , gamma=grid.best_params_['gamma']))
svm.fit(train_pca_w_smote, y_SMOTE)
predictions = svm.predict(X_test_w_pca)
f1 = f1_score(y_test_w, predictions, average = 'weighted')

#Apply 5 fold cross validation scoring to make sure results are reliable
# Print and save output
output_file = open('../output/test_set_output', 'a')
model_no = 'Model #: 10\n'
model_type = 'SVM with Hyperparameter tuning, PCA, SMOTE, and Min Max Scaler (wav data only)\n'
model_scores = f'F1 Score: {f1}\n'
output_file.writelines([model_no, model_type, model_scores])
output_file.close()
print("Test Set F1-score: {:.2%}".format(f1))
# Out:
# Test Set F1-score: 39.48%

# %% [markdown]
# ### Naive Bayes - Baseline

# %%
gnb = GaussianNB()
gnb.fit(X_train_w,y_train_w)
predictions = gnb.predict(X_test_w)
f1 = f1_score(y_test_w, predictions, average = 'weighted')

output_file = open('../output/test_set_output', 'a')
model_no = 'Model #: 11\n'
model_type = 'Naive Bayes Baseline Model (wav data only)\n'
model_scores = f'F1 Score: {f1}\n'
output_file.writelines([model_no, model_type, model_scores])
output_file.close()
print("Test Set F1-score: {:.2%}".format(f1))
# Out:
# Test Set F1-score: 60.57%

# %% [markdown]
# ### Logistic Regression - w/PCA

# %%
pca = PCA(n_components = 5)
pca.fit(X_train_w)
X_train_pca = pca.transform(X_train_w)
X_test_w_pca = pca.transform(X_test_w)

lr = LogisticRegression(C = 0.5, max_iter = 100,solver='liblinear', multi_class='auto')
lr.fit(X_train_pca,y_train_w)
predictions = lr.predict(X_test_w_pca)
f1 = f1_score(y_test_w, predictions, average = 'weighted')

output_file = open('../output/test_set_output', 'a')
model_no = 'Model #: 12\n'
model_type = 'Logistic Regression with PCA (wav data only)\n'
model_scores = f'F1 Score: {f1}\n'
output_file.writelines([model_no, model_type, model_scores])
output_file.close()
print("Test Set F1-score: {:.2%}".format(f1))
# Out:
# Test Set F1-score: 54.79%

# %% [markdown]
# ### SVM - Baseline

# %%
#Create baseline SVM model with Spectral Data

svm = make_pipeline(SVC())
svm.fit(X_train_w, y_train_w.values.ravel())
predictions = svm.predict(X_test_w)
f1 = f1_score(y_test_w, predictions, average = 'weighted')

# prints and saves output
output_file = open('../output/test_set_output', 'a')
model_no = 'Model #: 13\n'
model_type = 'SVM Baseline Model (wav data only)\n'
model_scores = f'F1 Score: {f1}\n'
output_file.writelines([model_no, model_type, model_scores])
output_file.close()
print("Test Set F1-score: {:.2%}".format(f1))
# Out:
# Test Set F1-score: 47.05%

# %% [markdown]
# ## Final Test Results
# |       |               Model |                                          Model Variant | Mean CV F1 Score | Test Set F1 Score |
# |-------|--------------------:|-------------------------------------------------------:|-----------------:|-------------------|
# | 6.1.1 |      Neural Network |                       Baseline (ADAM, 5 Hidden Layers) |             100% | 73.1%             |
# | 4.1.2 |       Random Forest |                                                w/SMOTE |           99.60% | 69.14%            |
# | 5.1.4 |                 SVM |                  w/Hyperparameter Tuning + PCA + SMOTE |           99.40% | 72.81%            |
# | 5.1.6 |                 SVM | w/Hyperparameter Tuning + PCA + SMOTE + StandardScaler |           96.30% | 68.41%            |
# | 1.1.1 | Logistic Regression |                                               Baseline |           94.40% | 72.76%            |
# | 5.1.2 |                 SVM |                                w/Hyperparameter Tuning |           90.40% | 70.17%            |
# | 5.1.3 |                 SVM |                          w/Hyperparameter Tuning + PCA |           89.10% | 66.30%            |
# | 4.1.1 |       Random Forest |                                               Baseline |           78.60% | 64.01%            |
# | 3.1.1 |       Decision Tree |                                               Baseline |           71.40% | 68.29%            |
# | 5.1.5 |                 SVM |   w/Hyperparameter Tuning + PCA + SMOTE + MinMaxScaler |           70.20% | 34.85%            |
# | 2.1.1 |         Naive Bayes |                                               Baseline |           66.70% | 60.57%            |
# | 1.1.2 | Logistic Regression |                                                  w/PCA |           59.20% | 54.79%            |
# | 5.1.1 |                 SVM |                                               Baseline |           54.20% | 47.05%            |

# %% [markdown]
# # Conclusion:
# Best performing model is Neural Network with F1-Score of 73.1%, followed by SVM F1-Score 72.81% and Logistic Regression at 72.76%. This shows that our models are able to sucessfully generalize.
#
# We recognize that the test result is lower than the result on development set cross validation. That is expected because SMOTE algorithm removes low frequency samples (below 6) on the training but requires that no modifications be done on the test data. As a result, ensemble types which have been removed from the train set but still exist in the test set will be misclassified. In return, the model receives more simulated data for training to improve its performance. A balance needs to be struck there.
#
# In comparing to current research in this domain, our project's dataset has a lot more complexity with 21 instrument ensemble combinations and polyphonic music from multiple instruments. Whereas existing research conducted was for soundbytes of 10 seconds for single instruments where 99%-100% accuracy was achieved for 4-10 types of instruments.
#
# We hope that our research can help contribute to business and academic efforts in this area due to its complexity being most similar to music that is typically encountered in real life business scenarios e.g. when users play music from playlists.
#
# We envision that our work can be used to identify musical attributes (such as combinations of instruments) that music lovers prefer and be used by companies in the tech and music industry to recommend music that meets user tastes and preferences.
